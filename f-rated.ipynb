# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
# import re
# import json
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import random
from numpy import NaN as nan
import csv

# %%
driver = webdriver.Chrome()

# %%
# f-rated 

driver = webdriver.Chrome()
# all_links = []
links = []
ref = 'https://www.imdb.com/search/keyword/?keywords=f-rated&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=bdc91cb7-0144-4906-b072-b45760c8aa67&pf_rd_r=7Z3ZH5FX7XE2AWRFJDEE&pf_rd_s=right-1&pf_rd_t=15051&pf_rd_i=genre&ref_=kw_nxt&mode=detail&'
prod = '&title_type=movie&sort=user_rating,desc'
for i in range(31,41,1):
    time.sleep(random.uniform(2,4))
    url = ref + 'page=' + str(i) + prod
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    divs = soup.find('div', {'class':'lister-list'}).find_all('div', {'class':'lister-item mode-detail'})
    for div in divs:
        a = div.find('a').get('href')
        links.append(a)
#     all_links.append(links)

# %%
data_for_all_links = pd.DataFrame([])
all_links_ser = pd.Series(a)
len_list = range(0,len(all_links_ser))
link = 'https://www.imdb.com'

for i in links:
#     data_for_some_links = pd.DataFrame([])
#     for j in i:
#         print(j)
    url = link + i
    print(url)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')

    try:
        data_for_dir = soup.find('div', {'class':'credit_summary_item'})
        a = data_for_dir.find('a')
        director = list(a)[0]
    except AttributeError:
        director = nan
    except IndexError:
        director = nan

    # жанры
    try:
        div = soup.find('div', {'id':'titleStoryLine'}).contents[19]
        gen = div.find_all('a')
        genres = []
        for i in gen:
            genres.append(i.string)
    except AttributeError:
        genres = nan
    except IndexError:
        genres = nan

    # сценарист
    try:
        div = soup.find('div', {'class':'plot_summary'}).contents[5]
        gen = div.find_all('a')
        writer = list(gen[0])[0]
    #     writers = []
    #     for i in gen:
    #         writers.append(i.text)
    except AttributeError:
        writer = nan
    except IndexError:
        writer = nan

    # название    
    try:
        name = soup.find('div', {'class':'originalTitle'}).text
    except AttributeError:
        name = nan
    except IndexError:
        name = nan    

    # дата релиза
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        date_release = data[3]
    except AttributeError:
        date_release = nan
    except IndexError:
        date_release = nan

    # бюджет
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        budget = data[6]
    except AttributeError:
        budget = nan
    except IndexError:
        budget = nan    

    # кассовые сборы в первую неделю (в сша)    
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        opening_weekend_usa = data[7]
    except AttributeError:
        opening_weekend_usa = nan
    except IndexError:
        opening_weekend_usa = nan

    # кассовые сборы в сша    
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        gross_usa = data[8]
    except AttributeError:
        gross_usa = nan
    except IndexError:
        gross_usa = nan    

    # кассовые сборы в мире
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        cumulative_worldwide_gross = data[9]
    except AttributeError:
        cumulative_worldwide_gross = nan
    except IndexError:
        cumulative_worldwide_gross = nan    


    # страна производства
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.find_all('a')
            data.append(a)
        country = list(data[1][0])[0]
    except AttributeError:
        country = nan
    except IndexError:
        country = nan

    # компания производства
    try:
        production_co = soup.find('div', {'id':'titleDetails'}).contents[37].contents[3].contents[0]
    except IndexError:
        production_co = nan
    except AttributeError:
        production_co = nan


    # описание (синопсис)
    try:
        div = soup.find('div', {'id':'titleStoryLine'})
        gen = div.find_all('div', {'class':'inline canwrap'})
        data = []
        for i in gen:
            a = i.find_all('span')
            data.append(a)
        description = list(data[0][0])[0]
    except IndexError:
        description = nan
    except AttributeError:
        description = nan

    # длительность
    try:
        divs = soup.find('div', {'class':'title_wrapper'}) # для длительности фильма
        run_time = divs.contents[5].contents[3].contents[0]
        # div = divs.find('time', {'datetime':'PT125M'})
        # run_time = div.contents[0].string
    except IndexError:
        run_time = nan
    except AttributeError:
        run_time = nan


    # возрастной рейтинг
    try:
        divs = soup.find('div', {'class':'title_wrapper'}) # для возрастного рейтинга
        div = divs.find('div', {'class':'subtext'})
        age_rating = div.contents[0]
    except IndexError:
        age_rating = nan
    except AttributeError:
        age_rating = nan


    # метаскоре
    try:
        div = soup.find('div', {'class':'titleReviewBarItem'}) # для метаскора (узнать, что такое метаскор)
        meta = div.find_all('span')
        list_for_meta = []
        for i in meta:
            list_for_meta.append(i.string)
        metascore = list_for_meta[0]
    except IndexError:
        metascore = nan
    except AttributeError:
        metascore = nan

    # рейтинг IMdb
    try:
        div = soup.find('div', {'class':'imdbRating'}) # рейтинг IMdb, кол-во отзывов и крит. рецензий
        imdb_rat = div.find_all('span')
        list_for_imdb_rat = []
        for i in imdb_rat:
            list_for_imdb_rat.append(i.string)
        imdb_rating = list_for_imdb_rat[0]
    except IndexError:
        imdb_rating = nan
    except AttributeError:
        imdb_rating = nan


    # количество проголосовавших
    try:
        div = soup.find('div', {'class':'imdbRating'}) # рейтинг IMdb, кол-во отзывов и крит. рецензий
        imdb_rat = div.find_all('span')
        list_for_imdb_rat = []
        for i in imdb_rat:
            list_for_imdb_rat.append(i.string)
        all_who_put_rating = list_for_imdb_rat[3]
    except IndexError:
        all_who_put_rating = nan
    except AttributeError:
        all_who_put_rating = nan    

    # количество тех, кто оставил отзыв
    try:
        div = soup.find('div', {'class':'imdbRating'}) # рейтинг IMdb, кол-во отзывов и крит. рецензий
        imdb_rat = div.find_all('span')
        list_for_imdb_rat = []
        for i in imdb_rat:
            list_for_imdb_rat.append(i.string)
        all_users_who_put_rewiew = list_for_imdb_rat[4]
    except IndexError:
        all_users_who_put_rewiew = nan
    except AttributeError:
        all_users_who_put_rewiew = nan


    # количество критиков, оставивших отзыв
    try:
        div = soup.find('div', {'class':'imdbRating'}) # рейтинг IMdb, кол-во отзывов и крит. рецензий
        imdb_rat = div.find_all('span')
        list_for_imdb_rat = []
        for i in imdb_rat:
            list_for_imdb_rat.append(i.string)
        all_critics_who_put_rewiew = list_for_imdb_rat[5]
    except IndexError:
        all_critics_who_put_rewiew = nan
    except AttributeError:
        all_critics_who_put_rewiew = nan

    # div = soup.find('div', {'class':'titleReviewBarItem titleReviewbarItemBorder'})
    # crit = div.find_all('a')
    # list_for_crit = []
    # for i in crit:
    #     print(i)
    #     list_for_crit.append(i.string)
    # all_new_users = list_for_crit[0]
    # all_new_critic = list_for_crit[1]


    data = (
        [name, director,writer,
         date_release, country, opening_weekend_usa, budget, gross_usa, 
         cumulative_worldwide_gross, production_co, 
         run_time, description,age_rating,
         metascore, all_users_who_put_rewiew,
         all_critics_who_put_rewiew, imdb_rating, all_who_put_rating
        ]
    )

    col = (
        ['Name','Director','Writer','Date_release', 
         'Country',
         'Opening_week_usa',
         'Budget', 'Gross',
         'Cum_world_gross','Production_co',
         'Run_time','Description',
         'Age_rating',
         'Metascore','Number_of_rewiews',
         'Number_of_critics','Imdb_rating','Number_of_who_rated']
    )

    total_data = (
    (pd.DataFrame(
    data,col
    )).transpose()
    )

    print(total_data)

    data_for_all_links = data_for_all_links.append(total_data)
    data_for_some_links = (data_for_all_links.append(total_data)).drop_duplicates()

    data_for_all_links.to_excel('C:/Users/1/Documents/Project/Data/f-rated_low.xlsx', index = False)

#         total_data = total_data.append(total_data)

#         data_for_some_links = (data_for_some_links.append(total_data)).drop_duplicates()

#     data_for_all_links = data_for_all_links.append(data_for_some_links)
# Out:
# https://www.imdb.com/title/tt0099776/?ref_=kw_li_i
#                              Name           Director             Writer  \
# 0  Europa Europa (original title)  Agnieszka Holland  Agnieszka Holland
#
#              Date_release Country     Opening_week_usa               Budget  \
# 0   Europa, Europa
#         German   $5,575,738           $5,575,738
#
#   Gross Cum_world_gross Production_co  \
# 0
#             »
#              NaN
#
#                                             Run_time  \
# 0
#                         1h 52min
#             ...
#
#                                          Description  \
# 0      A Jewish boy, separated from his family in...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             75           79 user         26 critic
#
#   Imdb_rating Number_of_who_rated
# 0         7,6              14 394
# https://www.imdb.com/title/tt0058985/?ref_=kw_li_i
#                           Name     Director       Writer  \
# 0  Le bonheur (original title)  Agnès Varda  Agnès Varda
#
#            Date_release Country Opening_week_usa Budget Gross Cum_world_gross  \
# 0   La felicidad
#         French
#    »
#
#    1.66 : 1
#
#
#   Production_co Run_time                                        Description  \
# 0           NaN        |      Francois is a young carpenter married with...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#       None           38 user         30 critic         7,6
#
#   Number_of_who_rated
# 0               4 583
# https://www.imdb.com/title/tt0426578/?ref_=kw_li_i
#                                                 Name        Director  \
# 0  Sophie Scholl - Die letzten Tage (original title)  Marc Rothemund
#
#                 Writer                      Date_release  Country  \
# 0  Fred Breinersdorfer   24 February 2005 (Germany)
#       Germany
#
#     Opening_week_usa      Budget                 Gross Cum_world_gross  \
# 0   $680,331           $17,310,
#    $10,804,315
#
#
#   Production_co Run_time                                        Description  \
# 0           NaN        |      The Final Days is the true story of German...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#         76          106 user        133 critic         7,6
#
#   Number_of_who_rated
# 0              25 625
# https://www.imdb.com/title/tt0047811/?ref_=kw_li_i
#                                       Name      Director          Writer  \
# 0  All That Heaven Allows (original title)  Douglas Sirk  Peggy Thompson
#
#   Date_release Country Opening_week_usa Budget Gross Cum_world_gross  \
# 0          NaN     NaN              NaN    NaN   NaN             NaN
#
#   Production_co Run_time                                        Description  \
# 0           NaN        |      Cary Scott is a widow with two grown child...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#       None          101 user         97 critic         7,6
#
#   Number_of_who_rated
# 0              12 472
# https://www.imdb.com/title/tt0054269/?ref_=kw_li_i
#                                                 Name     Director  \
# 0  Saturday Night and Sunday Morning (original ti...  Karel Reisz
#
#           Writer                              Date_release  Country  \
# 0  Alan Sillitoe   Lauantai-illasta sunnuntaiaamuun
#         English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#
#         89 min        |
#
#                                          Description Age_rating Metascore  \
# 0      Arthur, one of Britain's angry young men o...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           57 user         40 critic         7,6               7 234
# https://www.imdb.com/title/tt0109206/?ref_=kw_li_i
#                             Name       Director         Writer  \
# 0  Bandit Queen (original title)  Shekhar Kapur  Ranjit Kapoor
#
#                 Date_release Country   Opening_week_usa             Budget  \
# 0   Королева бандитов
#          Hindi   $399,748           $399,748
#
#   Gross Cum_world_gross Production_co Run_time  \
# 0
#             »
#              NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      The movie tells the story of the bandit qu...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           30 user         44 critic         7,6               4 113
# https://www.imdb.com/title/tt0040806/?ref_=kw_li_i
#                              Name        Director        Writer  \
# 0  The Snake Pit (original title)  Anatole Litvak  Frank Partos
#
#                  Date_release  Country Opening_week_usa Budget Gross  \
# 0   Die Schlangengrube
#         English             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#        108 min        |
#
#                                          Description Age_rating Metascore  \
# 0      Virginia Cunningham finds herself in a sta...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           72 user         40 critic         7,6               6 289
# https://www.imdb.com/title/tt0023775/?ref_=kw_li_i
#                          Name         Director       Writer  \
# 0  Baby Face (original title)  Alfred E. Green  Gene Markey
#
#                      Date_release  Country Opening_week_usa Budget Gross  \
# 0   A Mulher que Nos Perde
#         English             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#         71 min        |
#
#                                          Description Age_rating Metascore  \
# 0      Lilly (Baby Face) sleeps her way from base...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0          147 user         44 critic         7,6               5 821
# https://www.imdb.com/title/tt3949952/?ref_=kw_li_i
#   Name     Director       Writer                         Date_release  \
# 0  NaN  Uga Carlini  Uga Carlini   12 August 2016 (South Africa)
#
#
#         Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  South Africa
#
#    NaN             NaN           NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      When the going gets really tough, we need ...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None           15 user          8 critic         7,6
#
#   Number_of_who_rated
# 0                 699
# https://www.imdb.com/title/tt0339707/?ref_=kw_li_i
#                                     Name       Director         Writer  \
# 0  Song for a Raggy Boy (original title)  Aisling Walsh  Aisling Walsh
#
#               Date_release  Country Opening_week_usa Budget Gross  \
# 0   Песня для изгоя
#         English             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#         94 min        |
#
#                                          Description Age_rating Metascore  \
# 0      In 1939 William Franklin, an anti-Franco v...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           32 user         16 critic         7,6               3 673
# https://www.imdb.com/title/tt3856408/?ref_=kw_li_i
#                                                 Name      Director  \
# 0  Making Waves: The Art of Cinematic Sound (orig...  Midge Costin
#
#            Writer                 Date_release Country  Opening_week_usa  \
# 0  Bobette Buster   25 October 2019 (USA)
#          USA   $53,144
#
#        Budget             Gross Cum_world_gross Production_co Run_time  \
# 0   $12,348,
#    $63,998
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      An exploration of the history, artistry, a...
#         80
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            6 user         43 critic         7,6                 546
# https://www.imdb.com/title/tt3983674/?ref_=kw_li_i
#                                     Name                Director  \
# 0  The Mask You Live In (original title)  Jennifer Siebel Newsom
#
#             Writer                 Date_release Country Opening_week_usa  \
# 0  Jessica Anthony   25 January 2015 (USA)
#          USA
#
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0   »
#
#              NaN           NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Explores how our culture's narrow definiti...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           18 user          5 critic         7,6               2 248
# https://www.imdb.com/title/tt0023948/?ref_=kw_li_i
#                                Name      Director          Writer  \
# 0  Dinner at Eight (original title)  George Cukor  Frances Marion
#
#              Date_release  Country Opening_week_usa Budget Gross  \
# 0   Jantar às Oito
#         English             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#        111 min        |
#
#                                          Description Age_rating Metascore  \
# 0      Millicent Jordan is pre-occupied with the ...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           98 user         52 critic         7,6               7 145
# https://www.imdb.com/title/tt0024481/?ref_=kw_li_i
#                                Name          Director        Writer  \
# 0  Queen Christina (original title)  Rouben Mamoulian  H.M. Harwood
#
#                 Date_release  Country Opening_week_usa Budget Gross  \
# 0   Königin Christine
#         English             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#         99 min        |
#
#                                          Description Age_rating Metascore  \
# 0      Queen Christina of Sweden is a dominant Eu...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           67 user         42 critic         7,6               6 804
# https://www.imdb.com/title/tt0082252/?ref_=kw_li_i
#                                                 Name           Director  \
# 0  The Decline of Western Civilization (original ...  Penelope Spheeris
#
#            Writer        Date_release Country Opening_week_usa  \
# 0  Alice Bag Band   1983 (Italy)
#          USA
#
#
#                   Budget  Gross Cum_world_gross Production_co Run_time  \
# 0  $100,000
#                »
#
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      The Los Angeles punk music scene circa 198...
#         93
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           31 user         29 critic         7,6               3 316
# https://www.imdb.com/title/tt1784538/?ref_=kw_li_i
#                                    Name                Director        Writer  \
# 0  Miss Representation (original title)  Jennifer Siebel Newsom  Jacoba Atlas
#
#                         Date_release Country Opening_week_usa  \
# 0   15 April 2014 (Netherlands)
#          USA
#
#
#                   Budget  Gross Cum_world_gross Production_co Run_time  \
# 0  $750,000
#                »
#
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Explores the under-representation of women...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           22 user         16 critic         7,6               3 441
# https://www.imdb.com/title/tt5502816/?ref_=kw_li_i
#   Name     Director       Writer                      Date_release  \
# 0  NaN  Ga-eun Yoon  Ga-eun Yoon   16 June 2016 (South Korea)
#
#
#        Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  South Korea             »
#
#
#
#         95 min
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      At an age when perhaps friends mean more t...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            2 user          9 critic         7,6
#
#   Number_of_who_rated
# 0                 502
# https://www.imdb.com/title/tt0102141/?ref_=kw_li_i
#                                  Name     Director        Writer  \
# 0  Jacquot de Nantes (original title)  Agnès Varda  Jacques Demy
#
#       Date_release Country Opening_week_usa Budget Gross Cum_world_gross  \
# 0   Jacquot
#         French             »
#
#
#
#
#
#   Production_co Run_time                                        Description  \
# 0       118 min        |      Jacquot Demy is a little boy at the end of...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#       None           11 user         12 critic         7,6
#
#   Number_of_who_rated
# 0               1 255
# https://www.imdb.com/title/tt0910559/?ref_=kw_li_i
#                                      Name      Director        Writer  \
# 0  Kirschblüten - Hanami (original title)  Doris Dörrie  Doris Dörrie
#
#                    Date_release  Country   Opening_week_usa     Budget  \
# 0   6 March 2008 (Germany)
#       Germany   $104,589           $3,322,
#
#
#                   Gross Cum_world_gross Production_co Run_time  \
# 0   $12,861,658
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      When Trudi learns that her husband Rudi is...
#         62
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           31 user         71 critic         7,6               5 388
# https://www.imdb.com/title/tt5278596/?ref_=kw_li_i
#                       Name       Director         Writer  \
# 0  Weiner (original title)  Josh Kriegman  Josh Kriegman
#
#               Date_release Country     Opening_week_usa      Budget  \
# 0   26 May 2016 (USA)
#          USA   $1,676,108           $84,173,
#
#
#                  Gross Cum_world_gross Production_co  \
# 0   $1,715,955
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 36min
#             ...
#
#                              Description                   Age_rating  \
# 0      Serving seven consecutive terms,
#                     R
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0        84           55 user        129 critic         7,6
#
#   Number_of_who_rated
# 0               9 335
# https://www.imdb.com/title/tt0421229/?ref_=kw_li_i
#                                              Name     Director  \
# 0  Mrs. Palfrey at the Claremont (original title)  Dan Ireland
#
#            Writer Date_release Country Opening_week_usa Budget Gross  \
# 0  Martin Donovan          NaN     NaN              NaN    NaN   NaN
#
#   Cum_world_gross Production_co Run_time  \
# 0             NaN           NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Mrs. Palfrey (Dame Joan Plowright), recent...
#         67
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           53 user         28 critic         7,6               3 156
# https://www.imdb.com/title/tt5186608/?ref_=kw_li_i
#   Name       Director         Writer Date_release   Country Opening_week_usa  \
# 0  NaN  Nadine Truong  Nadine Truong         »
#     See more              NaN
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Depressed foster youth Ben is bullied and ...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user          1 critic         7,6                  37
# https://www.imdb.com/title/tt5310090/?ref_=kw_li_i
#                              Name       Director         Writer  \
# 0  Saala Khadoos (original title)  Sudha Kongara  Sudha Kongara
#
#                     Date_release Country  Opening_week_usa      Budget  \
# 0   29 January 2016 (India)
#        India   $76,931           $76,931,
#
#
#               Gross Cum_world_gross Production_co Run_time  \
# 0   $94,787
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      An under-fire boxing coach, Prabhu is tran...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           47 user         26 critic         7,6              10 701
# https://www.imdb.com/title/tt2741806/?ref_=kw_li_i
#                                     Name            Director  \
# 0  Grzeli nateli dgeebi (original title)  Nana Ekvtimishvili
#
#                Writer                       Date_release  Country  \
# 0  Nana Ekvtimishvili   19 September 2013 (Georgia)
#       Georgia
#
#    Opening_week_usa     Budget             Gross Cum_world_gross  \
# 0   $56,092           $9,280,
#    $97,236
#
#
#   Production_co Run_time                                        Description  \
# 0           NaN        |      Set in the Georgian capital of Tbilisi in ...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#         72           14 user         83 critic         7,6
#
#   Number_of_who_rated
# 0               6 311
# https://www.imdb.com/title/tt0028816/?ref_=kw_li_i
#                            Name         Director           Writer  \
# 0  Easy Living (original title)  Mitchell Leisen  Preston Sturges
#
#                   Date_release  Country Opening_week_usa Budget Gross  \
# 0   Mein Leben in Luxus
#         English
#    »
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      J.B. Ball, a rich financier, gets fed up w...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           38 user         17 critic         7,6               2 853
# https://www.imdb.com/title/tt2008006/?ref_=kw_li_i
#                       Name Director      Writer  \
# 0  Tou ze (original title)  Ann Hui  Susan Chan
#
#                      Date_release    Country   Opening_week_usa      Budget  \
# 0   9 March 2012 (Hong Kong)
#       Hong Kong   $191,826           $43,372,
#
#
#                  Gross Cum_world_gross Production_co Run_time  \
# 0   $4,776,272
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      After suffering a stroke, an altruistic ma...
#         78
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           23 user        105 critic         7,6               5 026
# https://www.imdb.com/title/tt0416991/?ref_=kw_li_i
#                         Name         Director           Writer  \
# 0  Moolaadé (original title)  Ousmane Sembene  Ousmane Sembene
#
#       Date_release  Country   Opening_week_usa             Budget Gross  \
# 0   Убежище
#         Bambara   $495,270           $215,646
#
#
#   Cum_world_gross Production_co Run_time  \
# 0            »
#              NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      In an African village this is the day when...
#         91
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           21 user         82 critic         7,6               3 397
# https://www.imdb.com/title/tt1172203/?ref_=kw_li_i
#                                     Name    Director      Writer  \
# 0  Sita Sings the Blues (original title)  Nina Paley  Nina Paley
#
#                     Date_release Country Opening_week_usa Budget Gross  \
# 0   12 August 2009 (France)
#          USA
#    »
#
#
#
#   Cum_world_gross  Production_co Run_time  \
# 0
#   Dolby Digital        |
#
#                                          Description Age_rating Metascore  \
# 0      The movie is about Sita, the Hindu Goddess...
#         93
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           42 user         63 critic         7,6               4 322
# https://www.imdb.com/title/tt0432325/?ref_=kw_li_i
#                                            Name           Director  \
# 0  Die Höhle des gelben Hundes (original title)  Byambasuren Davaa
#
#         Writer                  Date_release  Country Opening_week_usa  \
# 0  Abel Cantou   28 July 2005 (Germany)
#       Germany         $5,229,
#
#
#                     Budget              Gross      Cum_world_gross  \
# 0  EUR600,000
#                $141,803           $3,447,214
#
#                                        Production_co  \
# 0   Beauftragter der Bundesregierung für Angelege...
#
#                                             Run_time  \
# 0
#                         1h 33min
#             ...
#
#                                          Description  \
# 0      The little nomad girl Nansal finds a baby ...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     G
#             73           26 user         58 critic
#
#   Imdb_rating Number_of_who_rated
# 0         7,6               2 831
# https://www.imdb.com/title/tt2475154/?ref_=kw_li_i
#                      Name     Director       Writer  \
# 0  Elena (original title)  Petra Costa  Petra Costa
#
#                     Date_release Country  Opening_week_usa      Budget  \
# 0   September 2012 (Brazil)
#       Brazil   $25,788           $10,341,
#
#
#                Gross Cum_world_gross Production_co Run_time  \
# 0   $345,011                    »
#              NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Elena, a young Brazilian woman, travels to...
#         81
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            6 user         42 critic         7,6               1 519
# https://www.imdb.com/title/tt0826237/?ref_=kw_li_i
#   Name        Director            Writer        Date_release Country  \
# 0  NaN  Moufida Tlatli  Hélène Couturier   Rivalinnen
#         French
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#              NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      The relationships between women: those of ...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         7,6                  45
# https://www.imdb.com/title/tt4076648/?ref_=kw_li_i
#   Name    Director        Writer               Date_release Country  \
# 0  NaN  Susan Todd  Andrew Young   22 April 2018 (USA)
#          USA
#
#   Opening_week_usa                   Budget  Gross Cum_world_gross  \
# 0
#   $3,500,000
#                »
#
#
#
#   Production_co Run_time                                        Description  \
# 0           NaN      NaN      This large format digital film follows the...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#       None            1 user               NaN         7,6
#
#   Number_of_who_rated
# 0                  19
# https://www.imdb.com/title/tt5140248/?ref_=kw_li_i
#   Name       Director         Writer               Date_release Country  \
# 0  NaN  Estela Renner  Estela Renner   5 May 2016 (Brazil)
#       Brazil
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#
#            NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Discoveries in neuroscience can help us un...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            6 user          4 critic         7,6                 778
# https://www.imdb.com/title/tt5937296/?ref_=kw_li_i
#                      Name          Director            Writer   Date_release  \
# 0  Slava (original title)  Kristina Grozeva  Kristina Grozeva   Слава
#
#
#      Country  Opening_week_usa            Budget Gross Cum_world_gross  \
# 0  Bulgarian   $87,728           $18,415
#             »
#
#
#   Production_co Run_time                                        Description  \
# 0           NaN        |      A reclusive Bulgarian railway trackman fin...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#         83           12 user         70 critic         7,6
#
#   Number_of_who_rated
# 0               1 805
# https://www.imdb.com/title/tt0031750/?ref_=kw_li_i
#                             Name         Director          Writer  \
# 0  The Old Maid (original title)  Edmund Goulding  Casey Robinson
#
#                 Date_release  Country Opening_week_usa Budget Gross  \
# 0   Htjela sam dijete
#         English
#    »
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      After a two-year absence, Clem Spender ret...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           40 user         13 critic         7,6               3 005
# https://www.imdb.com/title/tt0022183/?ref_=kw_li_i
#                                   Name        Director           Writer  \
# 0  Mädchen in Uniform (original title)  Leontine Sagan  Christa Winsloe
#
#              Date_release Country Opening_week_usa Budget Gross  \
# 0   Brytningstider
#         German
#    »
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      German film in which a sensitive girl is s...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           28 user         24 critic         7,6               2 234
# https://www.imdb.com/title/tt1845773/?ref_=kw_li_i
#                                       Name        Director          Writer  \
# 0  Ai Weiwei: Never Sorry (original title)  Alison Klayman  Alison Klayman
#
#                       Date_release Country   Opening_week_usa      Budget  \
# 0   29 November 2012 (Russia)
#          USA   $534,100           $41,104,
#
#
#                Gross Cum_world_gross Production_co  \
# 0   $881,661
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 31min
#             ...
#
#                                          Description  \
# 0      AI WEIWEI: NEVER SORRY is the first featur...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             81            9 user        119 critic
#
#   Imdb_rating Number_of_who_rated
# 0         7,6               4 067
# https://www.imdb.com/title/tt0168269/?ref_=kw_li_i
#                         Name              Director           Writer  \
# 0  Zolushka (original title)  Nadezhda Kosheverova  Evgeniy Shvarts
#
#   Date_release Country Opening_week_usa Budget Gross Cum_world_gross  \
# 0          NaN     NaN              NaN    NaN   NaN             NaN
#
#   Production_co                                           Run_time  \
# 0           NaN
#                         1h 20min
#             ...
#
#                                          Description  \
# 0      A young woman forced into servitude by her...
#
#                      Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     0+
#           None           13 user          1 critic
#
#   Imdb_rating Number_of_who_rated
# 0         7,6               1 060
# https://www.imdb.com/title/tt4042850/?ref_=kw_li_i
#   Name     Director       Writer                    Date_release      Country  \
# 0  NaN  Paule Muret  Paule Muret   2 November 2016 (France)
#       Switzerland
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      This is the story of an encounter. An enco...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            0 user          3 critic         7,6                  23
# https://www.imdb.com/title/tt0077941/?ref_=kw_li_i
#   Name           Director             Writer Date_release Country  \
# 0  NaN  Ariane Mnouchkine  Ariane Mnouchkine          NaN     NaN
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0              NaN    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Who was Moliere? He is known everywhere as...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           22 user          2 critic         7,6                 749
# https://www.imdb.com/title/tt3113826/?ref_=kw_li_i
#   Name      Director        Writer                Date_release Country  \
# 0  NaN  Laurie Agard  Laurie Agard   28 July 2013 (Italy)
#        Italy
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#
#         94 min      NaN
#
#   Description Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0         NaN
#       None            0 user         10 critic
#
#   Imdb_rating Number_of_who_rated
# 0         7,6                  11
# https://www.imdb.com/title/tt2980626/?ref_=kw_li_i
#                          Name           Director             Writer  \
# 0  Twinsters (original title)  Samantha Futerman  Samantha Futerman
#
#                Date_release Country Opening_week_usa             Budget  \
# 0   17 July 2015 (USA)
#           UK
#    $100,575
#
#    Gross Cum_world_gross Production_co  \
# 0   »
#
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 29min
#             ...
#
#                                          Description  \
# 0      On February 21, 2013, Samantha, an America...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#             81           12 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         14 critic         7,6               4 584
# https://www.imdb.com/title/tt0119687/?ref_=kw_li_i
#                              Name      Director        Writer    Date_release  \
# 0  Moe no suzaku (original title)  Naomi Kawase  Naomi Kawase   Сузаку
#
#
#     Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  Japanese             »
#
#
#
#         95 min
#
#   Run_time                                        Description Age_rating  \
# 0        |      Depicts the life of a family in a remote J...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            6 user          4 critic         7,6
#
#   Number_of_who_rated
# 0               1 006
# https://www.imdb.com/title/tt5713856/?ref_=kw_li_i
#   Name       Director         Writer Date_release Country Opening_week_usa  \
# 0  NaN  Sarah Pirozek  Sarah Pirozek          NaN     NaN              NaN
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      "Woodstock teen, Rosie, mourning the first...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            0 user          9 critic         7,6                   9
# https://www.imdb.com/title/tt1620620/?ref_=kw_li_i
#                                  Name    Director      Writer  \
# 0  The Japanese Wife (original title)  Aparna Sen  Kunal Basu
#
#                  Date_release Country Opening_week_usa Budget Gross  \
# 0   9 April 2010 (India)
#        India
#    »
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Snehamoy Chatterjee lives a poor lifestyle...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           26 user         18 critic         7,6               1 999
# https://www.imdb.com/title/tt0081968/?ref_=kw_li_i
#   Name    Director      Writer           Date_release  Country  \
# 0  NaN  Aparna Sen  Aparna Sen   Magány út 36.
#         English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#
#            NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      After the marriage of her niece, Rosemary,...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            4 user               NaN         7,6                 359
# https://www.imdb.com/title/tt4150978/?ref_=kw_li_i
#   Name          Director            Writer Date_release  Country  \
# 0  NaN  Elizabeth Castle  Marcella Gilbert         »
#     English
#
#   Opening_week_usa          Budget Gross Cum_world_gross Production_co  \
# 0              NaN   1.78 : 1
#        NaN             NaN           NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      A documentary which details the life of La...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0       NaN               NaN               NaN         7,6
#
#   Number_of_who_rated
# 0                  27
# https://www.imdb.com/title/tt0391024/?ref_=kw_li_i
#                             Name        Director       Writer  \
# 0  Control Room (original title)  Jehane Noujaim  Julia Bacha
#
#                   Date_release Country Opening_week_usa               Budget  \
# 0   Контрольная комната
#         Arabic
#    $2,724,826
#
#    Gross Cum_world_gross Production_co Run_time  \
# 0   »
#
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      A chronicle which provides a rare window i...
#         79
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           95 user        108 critic         7,6               4 954
# https://www.imdb.com/title/tt4835456/?ref_=kw_li_i
#   Name       Director         Writer  \
# 0  NaN  Lucy van Beek  Lucy van Beek
#
#                                         Date_release  Country  \
# 0   Count-Down in ein neues Zeitalter: Hiroshima
# ...  English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0              NaN
#    NaN             NaN           NaN      NaN
#
#   Description Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0         NaN
#       None            8 user               NaN
#
#   Imdb_rating Number_of_who_rated
# 0         7,6                 177
# https://www.imdb.com/title/tt0092905/?ref_=kw_li_i
#                               Name       Director               Writer  \
# 0  Dolgie provody (original title)  Kira Muratova  Natalya Ryazantseva
#
#              Date_release  Country Opening_week_usa Budget Gross  \
# 0   Долгие проводы
#         Russian              NaN
#    NaN
#
#   Cum_world_gross Production_co  \
# 0             NaN           NaN
#
#                                             Run_time  \
# 0
#                         1h 37min
#             ...
#
#                                          Description  \
# 0      A single woman has put all her efforts int...
#
#                       Age_rating Metascore Number_of_rewiews  \
# 0
#                     12+
#           None            3 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0          2 critic         7,6                 545
# https://www.imdb.com/title/tt3410054/?ref_=kw_li_i
#   Name       Director         Writer Date_release  Country Opening_week_usa  \
# 0  NaN  Julia Huffman  Julia Huffman
#   English
#
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      After 40 years of protection, Grey wolves ...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            5 user          1 critic         7,6                 189
# https://www.imdb.com/title/tt2555202/?ref_=kw_li_i
#   Name    Director      Writer               Date_release Country  \
# 0  NaN  Al Reinert  Al Reinert   11 March 2013 (USA)
#          USA
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      'Our procedure has been always haunted by ...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            7 user          6 critic         7,6                 322
# https://www.imdb.com/title/tt3384218/?ref_=kw_li_i
#   Name   Director     Writer                   Date_release  Country  \
# 0  NaN  Anike Bay  Anike Bay   Girls Like Us! Part 2
#         English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#              NaN         Color      NaN
#
#                                          Description Age_rating Metascore  \
# 0      It's a story about a woman who must figure...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user               NaN         7,6                   8
# https://www.imdb.com/title/tt1710995/?ref_=kw_li_i
#   Name         Director       Writer        Date_release   Country  \
# 0  NaN  Laurice Guillen  Ricardo Lee   Only Yours
#         Filipino
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#              NaN         Color      NaN
#
#                                          Description Age_rating Metascore  \
# 0      As the eldest sibling, Dianne Alvero (Bea ...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            2 user          2 critic         7,6                  42
# https://www.imdb.com/title/tt2258685/?ref_=kw_li_i
#                                     Name      Director        Writer  \
# 0  The World Before Her (original title)  Nisha Pahuja  Nisha Pahuja
#
#                        Date_release Country Opening_week_usa Budget Gross  \
# 0   8 April 2014 (Netherlands)
#       Canada
#    »
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0             NaN           NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Ruhi Singh is a small town girl with big c...
#         77
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           13 user         24 critic         7,6                 800
# https://www.imdb.com/title/tt0117192/?ref_=kw_li_i
#   Name      Director        Writer     Date_release   Country  \
# 0  NaN  Sophie Calle  Sophie Calle   $2,769          See more
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      French Artist Sophie Calle and American Ph...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            2 user               NaN         7,6                 109
# https://www.imdb.com/title/tt2070768/?ref_=kw_li_i
#                      Name            Director              Writer  \
# 0  Palme (original title)  Kristina Lindström  Kristina Lindström
#
#                        Date_release Country Opening_week_usa Budget Gross  \
# 0   14 September 2012 (Sweden)
#       Sweden             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#        103 min        |
#
#                                          Description Age_rating Metascore  \
# 0      The life and times of Olof Palme, the prim...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            2 user          8 critic         7,6               1 422
# https://www.imdb.com/title/tt0446055/?ref_=kw_li_i
#                                          Name     Director            Writer  \
# 0  The Trials of Darryl Hunt (original title)  Ricki Stern  Evelyn Jefferson
#
#                Date_release Country Opening_week_usa                 Budget  \
# 0   January 2006 (USA)
#          USA           $619,
#   $200,000
#
#
#              Gross  Cum_world_gross      Production_co  \
# 0   $1,217           $1,217           Break Thru Films
#
#                                             Run_time  \
# 0
#                         1h 46min
#             ...
#
#                                          Description  \
# 0      "The Trials of Darryl Hunt" is a feature d...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#           None           10 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         12 critic         7,6                 965
# https://www.imdb.com/title/tt0051372/?ref_=kw_li_i
#   Name           Director             Writer            Date_release  \
# 0  NaN  Margot Benacerraf  Margot Benacerraf   1959 (Venezuela)
#
#
#      Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  Venezuela             »
#
#
#
#            NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      "Araya" is an old natural salt mine locate...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0        73            9 user         27 critic         7,6
#
#   Number_of_who_rated
# 0                 563
# https://www.imdb.com/title/tt1677642/?ref_=kw_li_i
#   Name      Director        Writer             Date_release Country  \
# 0  NaN  Judy Chaikin  Judy Chaikin   10 May 2013 (USA)
#          USA
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#              NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      In the world of jazz, women have long been...
#         90
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user          3 critic         7,6                 104
# https://www.imdb.com/title/tt0357283/?ref_=kw_li_i
#                                            Name      Director        Writer  \
# 0  Khamosh Pani: Silent Waters (original title)  Sabiha Sumar  Sabiha Sumar
#
#          Date_release  Country Opening_week_usa           Budget Gross  \
# 0   Тихие воды
#         Punjabi   $7,384           $7,384
#
#
#   Cum_world_gross Production_co Run_time  \
# 0            »
#              NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Set in 1979 Pakistan, General Zia-ul-Haq h...
#         64
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           25 user         33 critic         7,6               1 010
# https://www.imdb.com/title/tt0262504/?ref_=kw_li_i
#   Name         Director           Writer              Date_release Country  \
# 0  NaN  Tonia Marketaki  Tonia Marketaki   John the Violent
#          Greek
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      This film tells the story of Ioannis Zacho...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            2 user               NaN         7,6                  99
# https://www.imdb.com/title/tt5212792/?ref_=kw_li_i
#   Name       Director         Writer                  Date_release Country  \
# 0  NaN  Meghan O'Hara  Meghan O'Hara   25 November 2016 (USA)
#          USA
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A personal, important, surprising, and fun...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            0 user          2 critic         7,6                 283
# https://www.imdb.com/title/tt0080816/?ref_=kw_li_i
#   Name     Director           Writer         Date_release Country  \
# 0  NaN  Heidi Genée  Theodor Fontane   Greta Minde
#         German
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#    1.66 : 1
#                NaN      NaN
#
#   Description Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0         NaN
#        NaN               NaN               NaN
#
#   Imdb_rating Number_of_who_rated
# 0         7,6                  13
# https://www.imdb.com/title/tt1031928/?ref_=kw_li_i
#   Name           Director             Writer                    Date_release  \
# 0  NaN  Sandrine Bonnaire  Sandrine Bonnaire   30 January 2008 (France)
#
#
#   Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  France             »
#
#
#              NaN         Color
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      A sensitive portrait of Sabine Bonnaire, t...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            6 user         32 critic         7,6
#
#   Number_of_who_rated
# 0                 445
# https://www.imdb.com/title/tt0464189/?ref_=kw_li_i
#   Name          Director            Writer Date_release  Country  \
# 0  NaN  Victor Silverman  Victor Silverman
#   English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Documentary about transgender women and dr...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            3 user          4 critic         7,6                 121
# https://www.imdb.com/title/tt1226276/?ref_=kw_li_i
#   Name        Director          Writer                  Date_release Country  \
# ...
# https://www.imdb.com/title/tt0781436/?ref_=kw_li_i
#   Name         Director           Writer              Date_release Country  \
# 0  NaN  Carlos Molinero  Carlos Molinero   March 2006 (Spain)
#        Spain
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#              NaN           NaN      NaN
#
#   Description Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0         NaN
#       None            0 user          3 critic
#
#   Imdb_rating Number_of_who_rated
# 0         7,5                  22
# https://www.imdb.com/title/tt1340416/?ref_=kw_li_i
#   Name           Director             Writer  \
# 0  NaN  Andrea Oberheiden  Andrea Oberheiden
#
#                        Date_release  Country Opening_week_usa  \
# 0   23 February 2009 (Germany)
#       Germany
#
#
#                  Budget  Gross Cum_world_gross Production_co Run_time  \
# 0  $17,000
#                »
#
#            NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      On October 6th of 1927 the Warner Bros. pr...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         7,5                   8
# https://www.imdb.com/title/tt0915462/?ref_=kw_li_i
#   Name       Director         Writer                   Date_release Country  \
# 0  NaN  Charla Barker  Charla Barker   12 April 2008 (Croatia)
#          USA
#
#   Opening_week_usa Budget           Gross Cum_world_gross Production_co  \
# 0
#    »
#      1.33 : 1
#                  NaN           NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      With the 2008 U.S. presidential election f...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0       NaN               NaN               NaN         7,5
#
#   Number_of_who_rated
# 0                  31
# https://www.imdb.com/title/tt3398322/?ref_=kw_li_i
#   Name       Director         Writer               Date_release Country  \
# 0  NaN  Andrea Meller  Andrea Meller   24 April 2015 (USA)
#          USA
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Beyond the cameras and glamour of Hollywoo...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         7,5                   6
# https://www.imdb.com/title/tt0480673/?ref_=kw_li_i
#   Name                Director                  Writer     Date_release  \
# 0  NaN  Guadalupe Pérez García  Guadalupe Pérez García   $2,524
#
#    Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  Spanish
#
#
#              NaN         Color
#
#   Run_time Description Age_rating Metascore Number_of_rewiews  \
# 0      NaN         NaN
#        NaN               NaN
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN         7,5                  14
# https://www.imdb.com/title/tt0360793/?ref_=kw_li_i
#   Name          Director            Writer Date_release     Country  \
# 0  NaN  Izabel Jaguaribe  Izabel Jaguaribe
#   Portuguese
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0              NaN    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Documentary about Brazilian samba songwrit...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            0 user          3 critic         7,5                  94
# https://www.imdb.com/title/tt5297478/?ref_=kw_li_i
#   Name      Director        Writer                          Date_release  \
# 0  NaN  Suzanne Raes  Suzanne Raes   21 November 2015 (Netherlands)
#
#
#        Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  Netherlands
#
#    NaN             NaN           NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      Singer Boudewijn de Groot says farewell to...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0       NaN               NaN               NaN         7,5
#
#   Number_of_who_rated
# 0                  37
# https://www.imdb.com/title/tt0112877/?ref_=kw_li_i
#   Name            Director              Writer Date_release Country  \
# 0  NaN  Steffi Kammermeier  Steffi Kammermeier
#   German
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0              NaN
#    NaN             NaN           NaN      NaN
#
#   Description Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0         NaN
#       None            0 user          1 critic
#
#   Imdb_rating Number_of_who_rated
# 0         7,5                  11
# https://www.imdb.com/title/tt0160607/?ref_=kw_li_i
#   Name        Director          Writer Date_release Country Opening_week_usa  \
# 0  NaN  Christina Post  Christina Post
#      USA              NaN
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      GABBY retreats to her New Jersey hometown....
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         7,5                   8
# https://www.imdb.com/title/tt0415182/?ref_=kw_li_i
#   Name         Director           Writer Date_release     Country  \
# 0  NaN  Ginette Lavigne  Ginette Lavigne
#   Portuguese
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0              NaN
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      The operational commander of the "Captains...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         7,5                  11
# https://www.imdb.com/title/tt2176039/?ref_=kw_li_i
#   Name            Director              Writer  \
# 0  NaN  Desiree von Trotha  Desiree von Trotha
#
#                                         Date_release  Country  \
# 0   Woodstock in Timbuktu - Die Kunst des Widerst...  Germany
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#
#         90 min      NaN
#
#   Description Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0         NaN
#       None            0 user          6 critic
#
#   Imdb_rating Number_of_who_rated
# 0         7,5                   6
# https://www.imdb.com/title/tt0421633/?ref_=kw_li_i
#   Name      Director        Writer Date_release Country Opening_week_usa  \
# 0  NaN  Ewa Borzecka  Ewa Borzecka
#   Polish
#
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Arizona is a brand of cheap wine which hap...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         7,5                  60
# https://www.imdb.com/title/tt0783713/?ref_=kw_li_i
#   Name       Director         Writer                Date_release    Country  \
# 0  NaN  Monica Csango  Monica Csango   Pantotina diki sou
#         Norwegian
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#      NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A grandmother's everlasting love of her hu...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            0 user          1 critic         7,5                  20
# https://www.imdb.com/title/tt0155821/?ref_=kw_li_i
#   Name           Director         Writer         Date_release  Country  \
# 0  NaN  Sonia Herman Dolz  Leo Hannewijk   Black Tears
#         Spanish
#
#   Opening_week_usa Budget           Gross Cum_world_gross Production_co  \
# 0
#
#    1.66 : 1
#                  NaN           NaN
#
#   Run_time Description Age_rating Metascore Number_of_rewiews  \
# 0      NaN         NaN
#       None            1 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0          8 critic         7,5                 100
# https://www.imdb.com/title/tt1199536/?ref_=kw_li_i
#   Name       Director         Writer Date_release  Country Opening_week_usa  \
# 0  NaN  Hope Anderson  Hope Anderson
#   English
#
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0   »
#
#              NaN         Color      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A cultural history and present-day examina...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         7,5                   8
# https://www.imdb.com/title/tt0157311/?ref_=kw_li_i
#   Name          Director            Writer          Date_release Country  \
# 0  NaN  Martina Kudlácek  Martina Kudlácek   Sílená láska
#          Czech
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#   Description Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0         NaN
#        NaN               NaN               NaN
#
#   Imdb_rating Number_of_who_rated
# 0         7,5                   6
# https://www.imdb.com/title/tt2195020/?ref_=kw_li_i
#   Name    Director      Writer       Date_release Country Opening_week_usa  \
# 0  NaN  Lidia Duda  Lidia Duda   Entangled
#         Polish
#
#
#   Budget Gross Cum_world_gross Production_co Run_time Description Age_rating  \
# 0
#    NaN             NaN           NaN      NaN         NaN
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0       NaN               NaN               NaN         7,5
#
#   Number_of_who_rated
# 0                  11
# https://www.imdb.com/title/tt0322911/?ref_=kw_li_i
#                                    Name             Director  \
# 0  Kak stat muzhchinoy (original title)  Khasan Khazhkasimov
#
#                 Writer Date_release  Country Opening_week_usa Budget Gross  \
# 0  Nadezhda Grigoryeva
#   Russian
#
#    NaN
#
#   Cum_world_gross Production_co Run_time Description Age_rating Metascore  \
# 0             NaN           NaN      NaN         NaN
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         7,5                  12
# https://www.imdb.com/title/tt0400579/?ref_=kw_li_i
#   Name       Director         Writer                   Date_release  Country  \
# 0  NaN  Aelrun Goette  Aelrun Goette   11 March 2004 (Germany)
#       Germany
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#      NaN             NaN           NaN      NaN
#
#   Description Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0         NaN
#       None            0 user          9 critic
#
#   Imdb_rating Number_of_who_rated
# 0         7,5                  81
# https://www.imdb.com/title/tt1632460/?ref_=kw_li_i
#   Name       Director         Writer                    Date_release  Country  \
# 0  NaN  Marja Pensala  Marja Pensala   In Olonetsian Villages
#         Finnish
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#   Description Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0         NaN
#        NaN               NaN               NaN
#
#   Imdb_rating Number_of_who_rated
# 0         7,5                   6
# https://www.imdb.com/title/tt1207741/?ref_=kw_li_i
#   Name              Director                Writer  \
# 0  NaN  Anneta Papathanasiou  Anneta Papathanasiou
#
#                         Date_release Country Opening_week_usa Budget Gross  \
# 0   Qadir - An Afghan Ulysses
#          Greek              NaN
#    NaN
#
#   Cum_world_gross Production_co Run_time Description Age_rating Metascore  \
# 0             NaN           NaN      NaN         NaN
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         7,5                  13
# https://www.imdb.com/title/tt1475535/?ref_=kw_li_i
#   Name                Director                  Writer  \
# 0  NaN  Catherine Veaux-Logeat  Catherine Veaux-Logeat
#
#                      Date_release Country Opening_week_usa Budget Gross  \
# 0   2 October 2008 (Belgium)
#       Canada
#    »
#
#
#
#                       Cum_world_gross Production_co Run_time  \
# 0   1.78 : 1 / (high definition)
#                NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      The story of a woman whose husband is miss...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         7,5                  15
# https://www.imdb.com/title/tt0281021/?ref_=kw_li_i
#   Name              Director                Writer Date_release   Country  \
# 0  NaN  Marie-France Collard  Marie-France Collard
#   See more
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0              NaN
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Focusing on Levi Strauss and Co., this pro...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user               NaN         7,5                  10
# https://www.imdb.com/title/tt0417951/?ref_=kw_li_i
#   Name         Director           Writer                      Date_release  \
# 0  NaN  Irene Langemann  Irene Langemann   9 September 2004 (Germany)
#
#
#    Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  Germany
#    »
#
#              NaN           NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      Documentary about Brazilian pianist João C...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            1 user          3 critic         7,5
#
#   Number_of_who_rated
# 0                  22
# https://www.imdb.com/title/tt0765450/?ref_=kw_li_i
#                                                 Name                Director  \
# 0  Figner: The End of a Silent Century (original ...  Nathalie Alonso Casale
#
#                    Writer                       Date_release  Country  \
# 0  Nathalie Alonso Casale   Фигнер: Конец немого века
#         Russian
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#
#            DTS        |
#
#                                          Description Age_rating Metascore  \
# 0      A story about the almost unknown soviet ci...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            0 user          5 critic         7,5                  19
