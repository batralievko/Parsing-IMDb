# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
# import re
# import json
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import random
from numpy import NaN as nan
import csv

# %%
driver = webdriver.Chrome()

# %%
# teenager

driver = webdriver.Chrome()
# all_links = []
links = []
ref = 'https://www.imdb.com/search/keyword/?keywords=teenager&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=bdc91cb7-0144-4906-b072-b45760c8aa67&pf_rd_r=7Z3ZH5FX7XE2AWRFJDEE&pf_rd_s=right-1&pf_rd_t=15051&pf_rd_i=genre&ref_=kw_nxt&mode=detail&'
prod = '&title_type=movie&sort=user_rating,desc'
for i in range(21,31,1):
    time.sleep(random.uniform(2,4))
    url = ref + 'page=' + str(i) + prod
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    divs = soup.find('div', {'class':'lister-list'}).find_all('div', {'class':'lister-item mode-detail'})
    for div in divs:
        a = div.find('a').get('href')
        links.append(a)
#     all_links.append(links)

# %%
links
# Out:
# [u'/title/tt3746274/?ref_=kw_li_i',
#  u'/title/tt1493812/?ref_=kw_li_i',
#  u'/title/tt0411944/?ref_=kw_li_i',
#  u'/title/tt4132554/?ref_=kw_li_i',
#  u'/title/tt1462564/?ref_=kw_li_i',
#  u'/title/tt0167972/?ref_=kw_li_i',
#  u'/title/tt0370928/?ref_=kw_li_i',
#  u'/title/tt8286178/?ref_=kw_li_i',
#  u'/title/tt2077886/?ref_=kw_li_i',
#  u'/title/tt5702290/?ref_=kw_li_i',
#  u'/title/tt0125465/?ref_=kw_li_i',
#  u'/title/tt0099685/?ref_=kw_li_i',
#  u'/title/tt0187231/?ref_=kw_li_i',
#  u'/title/tt1420544/?ref_=kw_li_i',
#  u'/title/tt0760315/?ref_=kw_li_i',
#  u'/title/tt6751668/?ref_=kw_li_i',
#  u'/title/tt0163593/?ref_=kw_li_i',
#  u'/title/tt7936692/?ref_=kw_li_i',
#  u'/title/tt2075278/?ref_=kw_li_i',
#  u'/title/tt0088763/?ref_=kw_li_i',
#  u'/title/tt4154756/?ref_=kw_li_i',
#  u'/title/tt1675434/?ref_=kw_li_i',
#  u'/title/tt0095327/?ref_=kw_li_i',
#  u'/title/tt8080648/?ref_=kw_li_i',
#  u'/title/tt1217424/?ref_=kw_li_i',
#  u'/title/tt4154796/?ref_=kw_li_i',
#  u'/title/tt4633694/?ref_=kw_li_i',
#  u'/title/tt5311514/?ref_=kw_li_i',
#  u'/title/tt0101985/?ref_=kw_li_i',
#  u'/title/tt8294696/?ref_=kw_li_i',
#  u'/title/tt0104860/?ref_=kw_li_i',
#  u'/title/tt0058631/?ref_=kw_li_i',
#  u'/title/tt0288054/?ref_=kw_li_i',
#  u'/title/tt3300880/?ref_=kw_li_i',
#  u'/title/tt2848326/?ref_=kw_li_i',
#  u'/title/tt6083652/?ref_=kw_li_i',
#  u'/title/tt1700273/?ref_=kw_li_i',
#  u'/title/tt0923753/?ref_=kw_li_i',
#  u'/title/tt0075314/?ref_=kw_li_i',
#  u'/title/tt0066921/?ref_=kw_li_i',
#  u'/title/tt0110057/?ref_=kw_li_i',
#  u'/title/tt0049902/?ref_=kw_li_i',
#  u'/title/tt2438644/?ref_=kw_li_i',
#  u'/title/tt0100436/?ref_=kw_li_i',
#  u'/title/tt1912398/?ref_=kw_li_i',
#  u'/title/tt5340300/?ref_=kw_li_i',
#  u'/title/tt0377091/?ref_=kw_li_i',
#  u'/title/tt10204940/?ref_=kw_li_i',
#  u'/title/tt1921149/?ref_=kw_li_i',
#  u'/title/tt0103793/?ref_=kw_li_i',
#  u'/title/tt0101898/?ref_=kw_li_i',
#  u'/title/tt1233334/?ref_=kw_li_i',
#  u'/title/tt0072820/?ref_=kw_li_i',
#  u'/title/tt0070212/?ref_=kw_li_i',
#  u'/title/tt4375438/?ref_=kw_li_i',
#  u'/title/tt0271580/?ref_=kw_li_i',
#  u'/title/tt0081291/?ref_=kw_li_i',
#  u'/title/tt0055892/?ref_=kw_li_i',
#  u'/title/tt2364975/?ref_=kw_li_i',
#  u'/title/tt0054697/?ref_=kw_li_i',
#  u'/title/tt8092888/?ref_=kw_li_i',
#  u'/title/tt7205208/?ref_=kw_li_i',
#  u'/title/tt0291530/?ref_=kw_li_i',
#  u'/title/tt0168972/?ref_=kw_li_i',
#  u'/title/tt0059633/?ref_=kw_li_i',
#  u'/title/tt6535926/?ref_=kw_li_i',
#  u'/title/tt0051204/?ref_=kw_li_i',
#  u'/title/tt0284815/?ref_=kw_li_i',
#  u'/title/tt2548738/?ref_=kw_li_i',
#  u'/title/tt0084778/?ref_=kw_li_i',
#  u'/title/tt1426378/?ref_=kw_li_i',
#  u'/title/tt3379358/?ref_=kw_li_i',
#  u'/title/tt0325042/?ref_=kw_li_i',
#  u'/title/tt0205725/?ref_=kw_li_i',
#  u'/title/tt0041800/?ref_=kw_li_i',
#  u'/title/tt2274074/?ref_=kw_li_i',
#  u'/title/tt0102774/?ref_=kw_li_i',
#  u'/title/tt0254247/?ref_=kw_li_i',
#  u'/title/tt0085597/?ref_=kw_li_i',
#  u'/title/tt0085695/?ref_=kw_li_i',
#  u'/title/tt1818443/?ref_=kw_li_i',
#  u'/title/tt8110090/?ref_=kw_li_i',
#  u'/title/tt1098199/?ref_=kw_li_i',
#  u'/title/tt5214108/?ref_=kw_li_i',
#  u'/title/tt0314967/?ref_=kw_li_i',
#  u'/title/tt1937419/?ref_=kw_li_i',
#  u'/title/tt0098275/?ref_=kw_li_i',
#  u'/title/tt0075153/?ref_=kw_li_i',
#  u'/title/tt0076247/?ref_=kw_li_i',
#  u'/title/tt2059227/?ref_=kw_li_i',
#  u'/title/tt0369068/?ref_=kw_li_i',
#  u'/title/tt0097833/?ref_=kw_li_i',
#  u'/title/tt1161650/?ref_=kw_li_i']

# %%
data_for_all_links = pd.DataFrame([])
all_links_ser = pd.Series(a)
len_list = range(0,len(all_links_ser))
link = 'https://www.imdb.com'

for i in links:
#     data_for_some_links = pd.DataFrame([])
#     for j in i:
#         print(j)
    url = link + i
    print(url)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')

    try:
        data_for_dir = soup.find('div', {'class':'credit_summary_item'})
        a = data_for_dir.find('a')
        director = list(a)[0]
    except AttributeError:
        director = nan
    except IndexError:
        director = nan

    # жанры
    try:
        div = soup.find('div', {'id':'titleStoryLine'}).contents[19]
        gen = div.find_all('a')
        genres = []
        for i in gen:
            genres.append(i.string)
    except AttributeError:
        genres = nan
    except IndexError:
        genres = nan

    # сценарист
    try:
        div = soup.find('div', {'class':'plot_summary'}).contents[5]
        gen = div.find_all('a')
        writer = list(gen[0])[0]
    #     writers = []
    #     for i in gen:
    #         writers.append(i.text)
    except AttributeError:
        writer = nan
    except IndexError:
        writer = nan

    # название    
    try:
        name = soup.find('div', {'class':'originalTitle'}).text
    except AttributeError:
        name = nan
    except IndexError:
        name = nan    

    # дата релиза
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        date_release = data[3]
    except AttributeError:
        date_release = nan
    except IndexError:
        date_release = nan

    # бюджет
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        budget = data[6]
    except AttributeError:
        budget = nan
    except IndexError:
        budget = nan    

    # кассовые сборы в первую неделю (в сша)    
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        opening_weekend_usa = data[7]
    except AttributeError:
        opening_weekend_usa = nan
    except IndexError:
        opening_weekend_usa = nan

    # кассовые сборы в сша    
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        gross_usa = data[8]
    except AttributeError:
        gross_usa = nan
    except IndexError:
        gross_usa = nan    

    # кассовые сборы в мире
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        cumulative_worldwide_gross = data[9]
    except AttributeError:
        cumulative_worldwide_gross = nan
    except IndexError:
        cumulative_worldwide_gross = nan    


    # страна производства
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.find_all('a')
            data.append(a)
        country = list(data[1][0])[0]
    except AttributeError:
        country = nan
    except IndexError:
        country = nan

    # компания производства
    try:
        production_co = soup.find('div', {'id':'titleDetails'}).contents[37].contents[3].contents[0]
    except IndexError:
        production_co = nan
    except AttributeError:
        production_co = nan


    # описание (синопсис)
    try:
        div = soup.find('div', {'id':'titleStoryLine'})
        gen = div.find_all('div', {'class':'inline canwrap'})
        data = []
        for i in gen:
            a = i.find_all('span')
            data.append(a)
        description = list(data[0][0])[0]
    except IndexError:
        description = nan
    except AttributeError:
        description = nan

    # длительность
    try:
        divs = soup.find('div', {'class':'title_wrapper'}) # для длительности фильма
        run_time = divs.contents[5].contents[3].contents[0]
        # div = divs.find('time', {'datetime':'PT125M'})
        # run_time = div.contents[0].string
    except IndexError:
        run_time = nan
    except AttributeError:
        run_time = nan


    # возрастной рейтинг
    try:
        divs = soup.find('div', {'class':'title_wrapper'}) # для возрастного рейтинга
        div = divs.find('div', {'class':'subtext'})
        age_rating = div.contents[0]
    except IndexError:
        age_rating = nan
    except AttributeError:
        age_rating = nan


    # метаскоре
    try:
        div = soup.find('div', {'class':'titleReviewBarItem'}) # для метаскора (узнать, что такое метаскор)
        meta = div.find_all('span')
        list_for_meta = []
        for i in meta:
            list_for_meta.append(i.string)
        metascore = list_for_meta[0]
    except IndexError:
        metascore = nan
    except AttributeError:
        metascore = nan

    # рейтинг IMdb
    try:
        div = soup.find('div', {'class':'imdbRating'}) # рейтинг IMdb, кол-во отзывов и крит. рецензий
        imdb_rat = div.find_all('span')
        list_for_imdb_rat = []
        for i in imdb_rat:
            list_for_imdb_rat.append(i.string)
        imdb_rating = list_for_imdb_rat[0]
    except IndexError:
        imdb_rating = nan
    except AttributeError:
        imdb_rating = nan


    # количество проголосовавших
    try:
        div = soup.find('div', {'class':'imdbRating'}) # рейтинг IMdb, кол-во отзывов и крит. рецензий
        imdb_rat = div.find_all('span')
        list_for_imdb_rat = []
        for i in imdb_rat:
            list_for_imdb_rat.append(i.string)
        all_who_put_rating = list_for_imdb_rat[3]
    except IndexError:
        all_who_put_rating = nan
    except AttributeError:
        all_who_put_rating = nan    

    # количество тех, кто оставил отзыв
    try:
        div = soup.find('div', {'class':'imdbRating'}) # рейтинг IMdb, кол-во отзывов и крит. рецензий
        imdb_rat = div.find_all('span')
        list_for_imdb_rat = []
        for i in imdb_rat:
            list_for_imdb_rat.append(i.string)
        all_users_who_put_rewiew = list_for_imdb_rat[4]
    except IndexError:
        all_users_who_put_rewiew = nan
    except AttributeError:
        all_users_who_put_rewiew = nan


    # количество критиков, оставивших отзыв
    try:
        div = soup.find('div', {'class':'imdbRating'}) # рейтинг IMdb, кол-во отзывов и крит. рецензий
        imdb_rat = div.find_all('span')
        list_for_imdb_rat = []
        for i in imdb_rat:
            list_for_imdb_rat.append(i.string)
        all_critics_who_put_rewiew = list_for_imdb_rat[5]
    except IndexError:
        all_critics_who_put_rewiew = nan
    except AttributeError:
        all_critics_who_put_rewiew = nan

    # div = soup.find('div', {'class':'titleReviewBarItem titleReviewbarItemBorder'})
    # crit = div.find_all('a')
    # list_for_crit = []
    # for i in crit:
    #     print(i)
    #     list_for_crit.append(i.string)
    # all_new_users = list_for_crit[0]
    # all_new_critic = list_for_crit[1]


    data = (
        [name, director,writer,
         date_release, country, opening_weekend_usa, budget, gross_usa, 
         cumulative_worldwide_gross, production_co, 
         run_time, description,age_rating,
         metascore, all_users_who_put_rewiew,
         all_critics_who_put_rewiew, imdb_rating, all_who_put_rating
        ]
    )

    col = (
        ['Name','Director','Writer','Date_release', 
         'Country',
         'Opening_week_usa',
         'Budget', 'Gross',
         'Cum_world_gross','Production_co',
         'Run_time','Description',
         'Age_rating',
         'Metascore','Number_of_rewiews',
         'Number_of_critics','Imdb_rating','Number_of_who_rated']
    )

    total_data = (
    (pd.DataFrame(
    data,col
    )).transpose()
    )

    print(total_data)

    data_for_all_links = data_for_all_links.append(total_data)
    data_for_some_links = (data_for_all_links.append(total_data)).drop_duplicates()

    data_for_all_links.to_excel('C:/Users/1/Documents/Project/Data/teenager_low.xlsx', index = False)

#         total_data = total_data.append(total_data)

#         data_for_some_links = (data_for_some_links.append(total_data)).drop_duplicates()

#     data_for_all_links = data_for_all_links.append(data_for_some_links)
# Out:
# https://www.imdb.com/title/tt5774450/?ref_=kw_li_i
#                             Name         Director       Writer  \
# 0  Summer of 84 (original title)  François Simard  Matt Leslie
#
#                  Date_release Country Opening_week_usa            Budget  \
# 0   10 August 2018 (USA)
#          USA
#    $42,027
#
#    Gross Cum_world_gross Production_co Run_time  \
# 0   »
#
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      After suspecting that their police officer...
#         57
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0          327 user        134 critic         6,7              27 925
# https://www.imdb.com/title/tt6040662/?ref_=kw_li_i
#                                 Name      Director      Writer  \
# 0  The Children Act (original title)  Richard Eyre  Ian McEwan
#
#                 Date_release Country   Opening_week_usa      Budget  \
# 0   24 August 2018 (UK)
#           UK   $547,750           $76,108,
#
#
#                   Gross Cum_world_gross Production_co  \
# 0   $17,696,794
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 45min
#             ...
#
#                                          Description  \
# 0      As her marriage to Jack Faye (Stanley Tucc...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             62          108 user        117 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,7               9 315
# https://www.imdb.com/title/tt0118636/?ref_=kw_li_i
#                          Name      Director        Writer  \
# 0  Apt Pupil (original title)  Bryan Singer  Stephen King
#
#                Date_release  Country     Opening_week_usa         Budget  \
# 0   Способный ученик
#         English   $8,863,193           $3,583,151,
#
#
#                  Gross Cum_world_gross Production_co  \
# 0   $8,863,193
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 51min
#             ...
#
#                                          Description  \
# 0      Neighborhood boy Todd Bowden (Brad Renfro)...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             51          259 user        129 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,7              34 416
# https://www.imdb.com/title/tt0089470/?ref_=kw_li_i
#                                          Name         Director  \
# 0  The Legend of Billie Jean (original title)  Matthew Robbins
#
#            Writer Date_release Country Opening_week_usa Budget Gross  \
# 0  Mark Rosenthal          NaN     NaN              NaN    NaN   NaN
#
#   Cum_world_gross Production_co  \
# 0             NaN           NaN
#
#                                             Run_time  \
# 0
#                         1h 36min
#             ...
#
#                                          Description  \
# 0      Average Texas teen, Billie Jean Davy, is c...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#             45           88 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         39 critic         6,7               8 391
# https://www.imdb.com/title/tt0332375/?ref_=kw_li_i
#                       Name        Director          Writer       Date_release  \
# 0  Saved! (original title)  Brian Dannelly  Brian Dannelly   Спасённая
#
#
#    Country     Opening_week_usa       Budget                 Gross  \
# 0  English   $8,940,582           $345,136,
#    $10,275,509
#
#   Cum_world_gross Production_co  \
# 0
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 32min
#             ...
#
#                                          Description  \
# 0      Mary is a senior at American Eagle Christi...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#             62          330 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0        125 critic         6,7              43 712
# https://www.imdb.com/title/tt1316536/?ref_=kw_li_i
#                               Name    Director      Writer     Date_release  \
# 0  The Loved Ones (original title)  Sean Byrne  Sean Byrne   Любимые
#
#
#    Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  English             »
#
#
#
#         84 min
#
#                                             Run_time  \
# 0
#                         1h 24min
#             ...
#
#                                          Description  \
# 0      In order to avoid a ghostly figure in the ...
#
#                       Age_rating Metascore Number_of_rewiews  \
# 0
#                     18+
#           None          135 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0        195 critic         6,7              35 568
# https://www.imdb.com/title/tt7692966/?ref_=kw_li_i
#   Name     Director       Writer                 Date_release  Country  \
# 0  NaN  Ash Mayfair  Ash Mayfair   17 May 2019 (Vietnam)
#       Vietnam
#
#     Opening_week_usa            Budget Gross Cum_world_gross Production_co  \
# 0   $305,755           $84,933
#             »
#              NaN
#
#   Run_time                                        Description  \
# 0      NaN      In 19th century rural Vietnam, fourteen-ye...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             71            9 user         43 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,7               1 258
# https://www.imdb.com/title/tt0052847/?ref_=kw_li_i
#                       Name      Director           Writer  \
# 0  Gidget (original title)  Paul Wendkos  Gabrielle Upton
#
#                         Date_release  Country Opening_week_usa Budget Gross  \
# 0   April entdeckt die Männer
#         English
#    »
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Due to an accident while swimming in the s...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           43 user         18 critic         6,7               2 906
# https://www.imdb.com/title/tt1321860/?ref_=kw_li_i
#                           Name      Director       Writer   Date_release  \
# 0  The Beaver (original title)  Jodie Foster  Kyle Killen   Бобёр
#
#
#    Country   Opening_week_usa       Budget                Gross  \
# 0  English   $970,816           $107,577,
#    $7,294,800
#
#   Cum_world_gross Production_co  \
# 0
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 31min
#             ...
#
#                                          Description  \
# 0      Walter Black ('Mel Gibson') is depressed a...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#             60          164 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0        285 critic         6,7              46 103
# https://www.imdb.com/title/tt0054469/?ref_=kw_li_i
#                                   Name     Director        Writer  \
# 0  Where the Boys Are (original title)  Henry Levin  George Wells
#
#                    Date_release Country Opening_week_usa Budget Gross  \
# 0   28 December 1960 (USA)
#          USA             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Merritt, Melanie, Tuggle and Angie are fou...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           49 user         20 critic         6,7               2 248
# https://www.imdb.com/title/tt6400166/?ref_=kw_li_i
#                               Name     Director       Writer  \
# 0  Mi mejor amigo (original title)  Martín Deus  Martín Deus
#
#                         Date_release    Country Opening_week_usa  \
# 0   8 November 2018 (Argentina)
#       Argentina
#
#
#              Budget  Gross Cum_world_gross Production_co Run_time  \
# 0   $14,193           »
#
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Lorenzo is a quiet teenager who lives with...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           14 user          6 critic         6,7               1 852
# https://www.imdb.com/title/tt1553659/?ref_=kw_li_i
#                       Name     Director      Writer  \
# 0  Breath (original title)  Simon Baker  Gerard Lee
#
#                    Date_release    Country  Opening_week_usa     Budget  \
# 0   3 May 2018 (Australia)
#       Australia   $37,108           $5,258,
#
#
#                  Gross Cum_world_gross Production_co Run_time  \
# 0   $3,322,479
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Based on Tim Winton's award-winning and in...
#         71
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           47 user         39 critic         6,7               2 270
# https://www.imdb.com/title/tt0105810/?ref_=kw_li_i
#                                        Name    Director             Writer  \
# 0  Where the Day Takes You (original title)  Marc Rocco  Michael Hitchcock
#
#                     Date_release  Country   Opening_week_usa       Budget  \
# 0   День в Городе Ангелов
#         English   $390,152           $190,961,
#
#
#                Gross Cum_world_gross Production_co  \
# 0   $390,152
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 45min
#             ...
#
#                                          Description  \
# 0      A group of teen-age runaways try to surviv...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#           None           34 user         14 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,7               3 051
# https://www.imdb.com/title/tt0074798/?ref_=kw_li_i
#                          Name       Director      Writer  \
# 0  Lifeguard (original title)  Daniel Petrie  Ron Koslow
#
#             Date_release  Country Opening_week_usa               Budget  \
# 0   El salvavidas
#         English
#    $5,424,178
#
#    Gross Cum_world_gross Production_co Run_time  \
# 0   »
#
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Rick is in his 30s, but still works full-t...
#         54
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           30 user         20 critic         6,7               1 033
# https://www.imdb.com/title/tt0079813/?ref_=kw_li_i
#                                          Name      Director           Writer  \
# 0  Rock 'n' Roll High School (original title)  Allan Arkush  Richard Whitley
#
#          Date_release  Country Opening_week_usa Budget Gross Cum_world_gross  \
# 0   Disco High
#         English             »
#
#
#
#
#
#   Production_co Run_time                                        Description  \
# 0        93 min        |      Vince Lombardi High School keeps losing pr...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#         70           82 user         66 critic         6,7
#
#   Number_of_who_rated
# 0               8 473
# https://www.imdb.com/title/tt4270516/?ref_=kw_li_i
#                        Name    Director      Writer  \
# 0  Grandma (original title)  Paul Weitz  Paul Weitz
#
#                     Date_release Country Opening_week_usa  \
# 0   18 September 2015 (USA)
#          USA       $115,540,
#
#
#                   Budget                Gross      Cum_world_gross  \
# 0  $600,000
#                $6,980,524           $7,205,073
#
#      Production_co                                           Run_time  \
# 0   Depth of Field
#                         1h 19min
#             ...
#
#                                          Description  \
# 0      Lily Tomlin stars as Elle who has just got...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             77           76 user        145 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,7              14 096
# https://www.imdb.com/title/tt6053440/?ref_=kw_li_i
#                             Name      Director        Writer Date_release  \
# 0  Princess Cyd (original title)  Stephen Cone  Stephen Cone          NaN
#
#   Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0     NaN              NaN    NaN   NaN             NaN           NaN
#
#   Run_time Description Age_rating Metascore Number_of_rewiews  \
# 0        |         NaN
#         72           15 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         31 critic         6,7               2 516
# https://www.imdb.com/title/tt0098061/?ref_=kw_li_i
#                           Name      Director           Writer  \
# 0  Paperhouse (original title)  Bernard Rose  Catherine Storr
#
#                                  Date_release  Country   Opening_week_usa  \
# 0   Paperhouse - Alpträume werden wahr
#         English   $241,278
#
#               Budget Gross Cum_world_gross Production_co Run_time  \
# 0   $241,278
#             »
#              NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Anna is becoming lost in the loneliness of...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           68 user         35 critic         6,7               5 214
# https://www.imdb.com/title/tt0120692/?ref_=kw_li_i
#                        Name         Director           Writer Date_release  \
# 0  Strike! (original title)  Sarah Kernochan  Sarah Kernochan          NaN
#
#   Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0     NaN              NaN    NaN   NaN             NaN           NaN
#
#                                             Run_time  \
# 0
#                         1h 37min
#             ...
#
#                                          Description  \
# 0      If there's one thing this wild group of fr...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#             60           59 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         25 critic         6,7               6 352
# https://www.imdb.com/title/tt0099816/?ref_=kw_li_i
#                                 Name   Director            Writer  \
# 0  Haakon Haakonsen (original title)  Nils Gaup  O.V. Falck-Ytter
#
#                     Date_release Country Opening_week_usa  \
# 0   3 October 1990 (Norway)
#       Norway     $3,871,766,
#
#
#                        Budget                 Gross       Cum_world_gross  \
# 0  NOK60,000,000
#                $15,104,156           $15,104,156
#
#          Production_co Run_time  \
# 0   Filmkameratene A/S        |
#
#                                          Description Age_rating Metascore  \
# 0      Haakon Haakonsen didn't want to go to sea ...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           17 user         10 critic         6,7               2 321
# https://www.imdb.com/title/tt6410564/?ref_=kw_li_i
#                                    Name          Director            Writer  \
# 0  Sandome no satsujin (original title)  Hirokazu Koreeda  Hirokazu Koreeda
#
#                  Date_release Country  Opening_week_usa      Budget  \
# 0   17 May 2018 (Russia)
#        Japan   $89,315           $10,670,
#
#
#                   Gross Cum_world_gross Production_co Run_time  \
# 0   $13,411,936
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Misumi has a criminal record dating back m...
#         68
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           22 user        103 critic         6,7               4 645
# https://www.imdb.com/title/tt0082100/?ref_=kw_li_i
#                        Name         Director            Writer  \
# 0  La boum (original title)  Claude Pinoteau  Danièle Thompson
#
#       Date_release Country Opening_week_usa Budget Gross Cum_world_gross  \
# 0   Vi unge
#         French
#    »
#
#
#
#
#   Production_co Run_time                                        Description  \
# 0           NaN        |      13 years old Vic is new in her high school...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#       None           24 user          7 critic         6,7
#
#   Number_of_who_rated
# 0               7 666
# https://www.imdb.com/title/tt0112368/?ref_=kw_li_i
#                      Name              Director          Writer  \
# 0  Angus (original title)  Patrick Read Johnson  Chris Crutcher
#
#                Date_release  Country     Opening_week_usa  \
# 0   Станцуем, крошка
#         English   $4,821,759
#
#                 Budget Gross Cum_world_gross Production_co  \
# 0   $4,821,759
#             »
#              NaN
#
#                                             Run_time  \
# 0
#                         1h 30min
#             ...
#
#                                          Description  \
# 0      Angus is a large, pathetic 14 year old who...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#           None           59 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         23 critic         6,7               6 114
# https://www.imdb.com/title/tt0105572/?ref_=kw_li_i
#                           Name       Director           Writer  \
# 0  That Night (original title)  Craig Bolotin  Alice McDermott
#
#       Date_release  Country Opening_week_usa            Budget  Gross  \
# 0   Та ночь
#         English
#    $20,194           »
#
#
#   Cum_world_gross Production_co  \
# 0
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 29min
#             ...
#
#                                          Description  \
# 0      Alice, a ten-year-old girl, looks up to he...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#           None           31 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0          6 critic         6,7               2 371
# https://www.imdb.com/title/tt4636042/?ref_=kw_li_i
#                             Name      Director        Writer  \
# 0  Las elegidas (original title)  David Pablos  David Pablos
#
#                      Date_release Country Opening_week_usa Budget Gross  \
# 0   20 January 2016 (France)
#       Mexico             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Young Ulises falls in love with teen Sofia...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            4 user         24 critic         6,7               1 590
# https://www.imdb.com/title/tt0236157/?ref_=kw_li_i
#                           Name          Director      Writer  \
# 0  Disco Pigs (original title)  Kirsten Sheridan  Enda Walsh
#
#                       Date_release  Country Opening_week_usa Budget Gross  \
# 0   12 October 2001 (Ireland)
#       Ireland             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Pig and Runt - born on the same day, in th...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           49 user         12 critic         6,7               4 177
# https://www.imdb.com/title/tt0096171/?ref_=kw_li_i
#                              Name         Director           Writer  \
# 0  Stealing Home (original title)  Steven Kampmann  Steven Kampmann
#
#                    Date_release  Country     Opening_week_usa  \
# 0   Den största kärleken
#         English   $7,467,504
#
#                 Budget Gross Cum_world_gross Production_co Run_time  \
# 0   $7,467,504
#             »
#              NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Mark Harmon is a washed-up baseball player...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           53 user          7 critic         6,7               3 953
# https://www.imdb.com/title/tt1847746/?ref_=kw_li_i
#                        Name      Director        Writer  \
# 0  Wakolda (original title)  Lucía Puenzo  Lucía Puenzo
#
#                           Date_release    Country Opening_week_usa  \
# 0   19 September 2013 (Argentina)
#       Argentina        $34,259,
#
#
#                     Budget              Gross      Cum_world_gross  \
# 0  $2,000,000
#                $418,392           $3,635,718
#
#                            Production_co  \
# 0   Historias Cinematograficas Cinemania
#
#                                             Run_time  \
# 0
#                         1h 33min
#             ...
#
#                                          Description  \
# 0      Patagonia, 1960. A German doctor (Alex Bre...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#             62           27 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         93 critic         6,7               6 167
# https://www.imdb.com/title/tt0162236/?ref_=kw_li_i
#                             Name         Director         Writer Date_release  \
# 0  Just Looking (original title)  Jason Alexander  Marshall Karp          NaN
#
#   Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0     NaN              NaN    NaN   NaN             NaN           NaN
#
#                                             Run_time  \
# 0
#                         1h 37min
#             ...
#
#                                          Description  \
# 0      It's 1955 and curious 14-year-old Bronx ki...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             45           25 user         19 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,7               1 372
# https://www.imdb.com/title/tt0359423/?ref_=kw_li_i
#                                               Name       Director  \
# 0  A Home at the End of the World (original title)  Michael Mayer
#
#                Writer               Date_release  Country  \
# 0  Michael Cunningham   Дом на краю света
#         English
#
#       Opening_week_usa      Budget                Gross Cum_world_gross  \
# 0   $1,029,872           $64,728,
#    $1,644,653
#
#
#   Production_co                                           Run_time  \
# 0           NaN
#                         1h 37min
#             ...
#
#                                          Description  \
# 0      From the Pulitzer Prize-winning author of ...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             59          133 user         48 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,7              12 975
# https://www.imdb.com/title/tt0242795/?ref_=kw_li_i
#                             Name            Director              Writer  \
# 0  Presque rien (original title)  Sébastien Lifshitz  Sébastien Lifshitz
#
#            Date_release Country Opening_week_usa             Budget  Gross  \
# 0   Почти ничего
#         French
#    $326,484           »
#
#
#   Cum_world_gross Production_co  \
# 0
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 38min
#             ...
#
#                                          Description  \
# 0      Eighteen-year-old Mathieu vacations at the...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             68           57 user         29 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,7               4 663
# https://www.imdb.com/title/tt3882000/?ref_=kw_li_i
#                                  Name       Director         Writer  \
# 0  Microbe et Gasoil (original title)  Michel Gondry  Michel Gondry
#
#   Date_release Country Opening_week_usa Budget Gross Cum_world_gross  \
# 0          NaN     NaN              NaN    NaN   NaN             NaN
#
#   Production_co                                           Run_time  \
# 0           NaN
#                         1h 45min
#             ...
#
#                                          Description  \
# 0      Two young friends embark on a road trip ac...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             75            8 user         59 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,7               2 267
# https://www.imdb.com/title/tt0138414/?ref_=kw_li_i
#                                  Name       Director         Writer  \
# 0  Edge of Seventeen (original title)  David Moreton  Todd Stephens
#
#                       Date_release Country Opening_week_usa  \
# 0   20 April 2000 (Australia)
#          USA         $5,302,
#
#
#                   Budget              Gross    Cum_world_gross  \
# 0  $700,000
#                $871,759           $871,759
#
#         Production_co Run_time  \
# 0   Blue Streak Films        |
#
#                                          Description Age_rating Metascore  \
# 0      A gay teen finds out who he is and what he...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           72 user         19 critic         6,7               5 475
# https://www.imdb.com/title/tt0058756/?ref_=kw_li_i
#                                          Name         Director        Writer  \
# 0  The World of Henry Orient (original title)  George Roy Hill  Nora Johnson
#
#                          Date_release  Country Opening_week_usa Budget Gross  \
# 0   Deux copines, un séducteur
#         English
#    »
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Henry Orient (Peter Sellers) is a madly eg...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           59 user         27 critic         6,7               3 032
# https://www.imdb.com/title/tt0300270/?ref_=kw_li_i
#                              Name         Director               Writer  \
# 0  La niña santa (original title)  Lucrecia Martel  Juan Pablo Domenech
#
#   Date_release Country Opening_week_usa Budget Gross Cum_world_gross  \
# 0          NaN     NaN              NaN    NaN   NaN             NaN
#
#   Production_co                                           Run_time  \
# 0           NaN
#                         1h 46min
#             ...
#
#                                          Description  \
# 0      ENT physicians gather at a provincial hote...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             75           38 user         78 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,7               3 461
# https://www.imdb.com/title/tt3230162/?ref_=kw_li_i
#                                  Name      Director        Writer  \
# 0  Futatsume no mado (original title)  Naomi Kawase  Naomi Kawase
#
#                  Date_release Country Opening_week_usa             Budget  \
# 0   26 July 2014 (Japan)
#       France
#    $383,948
#
#    Gross Cum_world_gross Production_co Run_time  \
# 0   »
#
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      On the subtropical Japanese island of Amam...
#         55
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            8 user         82 critic         6,7               2 400
# https://www.imdb.com/title/tt0094869/?ref_=kw_li_i
#                                  Name      Director          Writer  \
# 0  The Chocolate War (original title)  Keith Gordon  Robert Cormier
#
#                     Date_release  Country   Opening_week_usa  \
# 0   A Guerra do Chocolate
#         English   $303,624
#
#               Budget Gross Cum_world_gross Production_co Run_time  \
# 0   $303,624
#             »
#              NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      A surreal portrait of a Catholic Private S...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           42 user         25 critic         6,7               1 975
# https://www.imdb.com/title/tt3144098/?ref_=kw_li_i
#                                 Name       Director         Writer  \
# 0  Dong-chang-saeng (original title)  Hong-soo Park  Soo-young Kim
#
#                           Date_release      Country     Opening_week_usa  \
# 0   6 November 2013 (South Korea)
#       South Korea   $6,834,802
#
#              Budget Gross Cum_world_gross Production_co Run_time  \
# 0   $76,543
#             »
#              NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      After his father's botched espionage missi...
#         36
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           11 user         31 critic         6,7               2 645
# https://www.imdb.com/title/tt1886502/?ref_=kw_li_i
#                              Name          Director            Writer  \
# 0  Corpo celeste (original title)  Alice Rohrwacher  Alice Rohrwacher
#
#             Date_release  Country   Opening_week_usa           Budget Gross  \
# 0   Небесное тело
#         Italian   $347,600           $8,919
#
#
#   Cum_world_gross Production_co Run_time  \
# 0            »
#              NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Set deep in the south of Italy, Corpo Cele...
#         65
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            5 user         53 critic         6,7               1 063
# https://www.imdb.com/title/tt7397338/?ref_=kw_li_i
#   Name       Director         Writer       Date_release Country  \
# 0  NaN  Claire Burger  Claire Burger   Real Love
#         French
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#
#         98 min      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Forbach, Eastern France. Present day. Sinc...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            2 user         10 critic         6,7                 338
# https://www.imdb.com/title/tt0258967/?ref_=kw_li_i
#                           Name        Director               Writer  \
# 0  The Unsaid (original title)  Tom McLoughlin  Christopher Murphey
#
#          Date_release  Country Opening_week_usa               Budget  Gross  \
# 0   Грехи отца
#         English
#    $2,154,571           »
#
#
#   Cum_world_gross Production_co  \
# 0
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 51min
#             ...
#
#                                          Description  \
# 0      Michael Hunter's lovely, beloved 17 year-o...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#           None           45 user         17 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,7               6 061
# https://www.imdb.com/title/tt2960450/?ref_=kw_li_i
#                                                 Name       Director  \
# 0  The Galapagos Affair: Satan Came to Eden (orig...  Daniel Geller
#
#            Writer Date_release Country Opening_week_usa Budget Gross  \
# 0  Dayna Goldfine          NaN     NaN              NaN    NaN   NaN
#
#   Cum_world_gross Production_co Run_time  \
# 0             NaN           NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Darwin meets Hitchcock in this feature-len...
#         69
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           14 user         39 critic         6,7               1 253
# https://www.imdb.com/title/tt3186946/?ref_=kw_li_i
#                      Name          Director            Writer Date_release  \
# 0  Xenia (original title)  Panos H. Koutras  Panos H. Koutras          NaN
#
#   Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0     NaN              NaN    NaN   NaN             NaN           NaN
#
#   Run_time                                        Description Age_rating  \
# 0        |      Strangers in their own birthplace, 16-year...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0        62            4 user         60 critic         6,7
#
#   Number_of_who_rated
# 0               3 365
# https://www.imdb.com/title/tt0168449/?ref_=kw_li_i
#                                                 Name      Director  \
# 0  The Adventures of Sebastian Cole (original title)  Tod Williams
#
#          Writer                      Date_release Country   Opening_week_usa  \
# 0  Tod Williams   11 September 1998 (Canada)
#          USA   $100,841
#
#        Budget              Gross Cum_world_gross Production_co  \
# 0   $12,598,
#    $100,841
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 39min
#             ...
#
#                                          Description  \
# 0      In June, 1983, in Dutchess County, New Yor...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#           None           21 user         28 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,7               1 801
# https://www.imdb.com/title/tt0095564/?ref_=kw_li_i
#                                 Name          Director          Writer  \
# 0  Madame Sousatzka (original title)  John Schlesinger  Bernice Rubens
#
#   Date_release Country Opening_week_usa Budget Gross Cum_world_gross  \
# 0          NaN     NaN              NaN    NaN   NaN             NaN
#
#   Production_co Run_time                                        Description  \
# 0           NaN        |      Bengali Sushila Sen and her son, Manek, re...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#       None           16 user          7 critic         6,7
#
#   Number_of_who_rated
# 0               1 269
# https://www.imdb.com/title/tt0246405/?ref_=kw_li_i
#                                  Name           Director             Writer  \
# 0  27 Missing Kisses (original title)  Nana Dzhordzhadze  Nana Dzhordzhadze
#
#                       Date_release  Country Opening_week_usa  \
# 0   14 February 2002 (Russia)
#       Germany
#
#
#                       Budget  Gross Cum_world_gross Production_co Run_time  \
# 0  DEM4,300,000
#                »
#
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      The summerly adventures of teen Sybilla, w...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           12 user         14 critic         6,7               1 301
# https://www.imdb.com/title/tt0039020/?ref_=kw_li_i
#   Name        Director                  Writer Date_release Country  \
# 0  NaN  Alfred Santell  Adela Rogers St. Johns          NaN     NaN
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0              NaN    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      The film begins on Mother's Day, 1938 when...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           11 user          1 critic         6,7                 190
# https://www.imdb.com/title/tt0042819/?ref_=kw_li_i
#   Name      Director           Writer             Date_release  Country  \
# 0  NaN  David Miller  F. Hugh Herbert   Vida de mi vida
#         English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#
#            NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Gail discovers the shocking news that she ...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           29 user          2 critic         6,7                 470
# https://www.imdb.com/title/tt6107516/?ref_=kw_li_i
#   Name                Director                  Writer        Date_release  \
# 0  NaN  Gustavo Rondón Córdova  Gustavo Rondón Córdova   The Family
#
#
#    Country Opening_week_usa           Budget  Gross Cum_world_gross  \
# 0  Spanish
#    $3,696           »
#
#
#
#   Production_co Run_time                                        Description  \
# 0           NaN      NaN      Andres (35) and his son Pedro (12) live in...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#       None            3 user         19 critic         6,7
#
#   Number_of_who_rated
# 0                 370
# https://www.imdb.com/title/tt3814316/?ref_=kw_li_i
#                           Name        Director         Writer  \
# 0  Le nouveau (original title)  Rudi Rosenberg  Igor Gotesman
#
#       Date_release Country Opening_week_usa Budget Gross Cum_world_gross  \
# 0   Новичок
#         French
#    »
#
#    1.85 : 1
#
#
#   Production_co Run_time                                        Description  \
# 0         Color        |      Benoit, the new kid at school, is bullied ...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#       None            2 user         29 critic         6,7
#
#   Number_of_who_rated
# 0               1 098
# https://www.imdb.com/title/tt0069771/?ref_=kw_li_i
#   Name       Director         Writer Date_release Country Opening_week_usa  \
# 0  NaN  Moshé Mizrahi  Rachel Fabien          NaN     NaN              NaN
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A fatherless family immigrates to Israel f...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            2 user          1 critic         6,7                 197
# https://www.imdb.com/title/tt0092247/?ref_=kw_li_i
#   Name Director        Writer                Date_release   Country  \
# 0  NaN    U Lan  Congwen Shen   Married to a Child
#         Mandarin
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#
#    2.35 : 1
#                NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      China, 1900. Xiaoxiao, a girl of about 12,...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            2 user               NaN         6,7                 156
# https://www.imdb.com/title/tt0052367/?ref_=kw_li_i
#   Name       Director          Writer Date_release Country Opening_week_usa  \
# 0  NaN  Basil Dearden  James Kennaway          NaN     NaN              NaN
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Struggle between a Liverpool Juvenile Liai...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           24 user          8 critic         6,7                 503
# https://www.imdb.com/title/tt1539325/?ref_=kw_li_i
#                                  Name       Director         Writer  \
# 0  Sandheden om mænd (original title)  Nikolaj Arcel  Nikolaj Arcel
#
#                 Date_release Country Opening_week_usa Budget Gross  \
# 0   Правда о мужчинах
#         Danish
#    »
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0             NaN         Color        |
#
#                                          Description Age_rating Metascore  \
# 0      Mads, a 34-year-old scriptwriter, goes thr...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user         15 critic         6,7               1 227
# https://www.imdb.com/title/tt0031709/?ref_=kw_li_i
#                                       Name         Director         Writer  \
# 0  Nancy Drew... Reporter (original title)  William Clemens  Kenneth Gamet
#
#   Date_release Country Opening_week_usa Budget Gross Cum_world_gross  \
# 0          NaN     NaN              NaN    NaN   NaN             NaN
#
#   Production_co Run_time                                        Description  \
# 0           NaN        |      While participating in a contest at a loca...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#       None           35 user         15 critic         6,7
#
#   Number_of_who_rated
# 0                 984
# https://www.imdb.com/title/tt6481478/?ref_=kw_li_i
#   Name              Director                Writer  \
# 0  NaN  Olivier Ayache-Vidal  Olivier Ayache-Vidal
#
#                        Date_release Country Opening_week_usa  \
# 0   13 September 2017 (France)
#       France
#
#
#                 Budget  Gross Cum_world_gross Production_co Run_time  \
# 0   $2,465,973           »
#
#            NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      François Foucault, veteran professor of Fr...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            2 user         13 critic         6,7                 810
# https://www.imdb.com/title/tt1756595/?ref_=kw_li_i
#                           Name       Director        Writer  \
# 0  Les géants (original title)  Bouli Lanners  Elise Ancion
#
#                       Date_release  Country Opening_week_usa  \
# 0   12 October 2011 (Belgium)
#       Belgium
#
#
#               Budget  Gross Cum_world_gross Production_co Run_time  \
# 0   $343,324           »
#
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Brothers Seth and Zak, fifteen and thirtee...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            7 user         34 critic         6,7               1 702
# https://www.imdb.com/title/tt2125425/?ref_=kw_li_i
#                        Name       Director         Writer  \
# 0  A Busca (original title)  Luciano Moura  Luciano Moura
#
#           Date_release     Country Opening_week_usa Budget Gross  \
# 0   Кресло отца
#         Portuguese
#    »
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0   1.85 : 1
#              Color        |
#
#                                          Description Age_rating Metascore  \
# 0      A man who has put his career ahead of ever...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            3 user         11 critic         6,7               1 223
# https://www.imdb.com/title/tt0066101/?ref_=kw_li_i
#   Name       Director         Writer Date_release Country Opening_week_usa  \
# 0  NaN  André Cayatte  André Cayatte          NaN     NaN              NaN
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A love story between a teacher, Daniele, 3...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user          3 critic         6,7                 270
# https://www.imdb.com/title/tt0041899/?ref_=kw_li_i
#   Name         Director         Writer             Date_release  Country  \
# 0  NaN  Mitchell Leisen  Ruth McKenney   A Grande Paixão
#         English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#
#            NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      In 1906 in Connecticut, Elisha Hunt, the 5...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            3 user               NaN         6,7                  58
# https://www.imdb.com/title/tt1110207/?ref_=kw_li_i
#                            Name     Director        Writer       Date_release  \
# 0  Bajo la sal (original title)  Mario Muñoz  Angel Pulido   Под солью
#
#
#    Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  Spanish             »
#
#
#
#        112 min
#
#   Run_time                                        Description Age_rating  \
# 0        |      A series of murders leads commander TRUJIL...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            5 user          4 critic         6,7
#
#   Number_of_who_rated
# 0               1 054
# https://www.imdb.com/title/tt0120872/?ref_=kw_li_i
#                             Name         Director         Writer  \
# 0  Tulennielijä (original title)  Pirjo Honkasalo  Pirkko Saisio
#
#                       Date_release  Country Opening_week_usa  \
# 0   30 October 1998 (Finland)
#       Finland
#
#
#                       Budget  Gross Cum_world_gross Production_co Run_time  \
# 0  FIM8,823,603
#                »
#
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      The twin sisters Helena and Irene are born...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            3 user          1 critic         6,7                 317
# https://www.imdb.com/title/tt1946285/?ref_=kw_li_i
#                                                 Name      Director  \
# 0  Kirin no tsubasa: Gekijouban Shinzanmono (orig...  Nobuhiro Doi
#
#             Writer            Date_release   Country Opening_week_usa Budget  \
# ...
# 0      NaN         NaN
#       None            3 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN         6,4                 438
# https://www.imdb.com/title/tt0077813/?ref_=kw_li_i
#   Name     Director        Writer            Date_release    Country  \
# 0  NaN  Rajko Ranfl  Branka Jurca   Kad jagode zru
#         Slovenian
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#
#              NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Jagoda Kopriva is a typical teenage girl w...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user               NaN         6,4                 102
# https://www.imdb.com/title/tt2290934/?ref_=kw_li_i
#   Name              Director            Writer          Date_release  Country  \
# 0  NaN  Leonardo di Costanzo  Maurizio Braucci   The Interval
#         Italian
#
#   Opening_week_usa             Budget  Gross Cum_world_gross Production_co  \
# 0
#    $255,267           »
#
#            NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      Because of an offense to a Camorra chief's...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            2 user         18 critic         6,4
#
#   Number_of_who_rated
# 0                 367
# https://www.imdb.com/title/tt1104783/?ref_=kw_li_i
#   Name      Director           Writer                 Date_release Country  \
# 0  NaN  Caroline Suh  George Zisiadis   15 October 2008 (USA)
#          USA
#
#    Opening_week_usa            Budget  Gross Cum_world_gross Production_co  \
# 0   $26,976           $26,976           »
#
#            NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      It's hard to run for office - even in high...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0        69            5 user         19 critic         6,4
#
#   Number_of_who_rated
# 0                 247
# https://www.imdb.com/title/tt1305837/?ref_=kw_li_i
#   Name     Director         Writer                             Date_release  \
# 0  NaN  Tomás Masín  Lubomír Drozd   25 November 2009 (Czech Republic)
#
#
#           Country   Opening_week_usa                   Budget Gross  \
# 0  Czech Republic   $502,475          $4,500,000
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0            »
#              NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A 19 year old nonconformist poet living in...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user         17 critic         6,4                 364
# https://www.imdb.com/title/tt0106240/?ref_=kw_li_i
#   Name                Director      Writer  \
# 0  NaN  Megan Simpson Huberman  Ken Catran
#
#                              Date_release  Country Opening_week_usa Budget  \
# 0   Alex: The Spirit of a Champion
#         English
#    »
#
#
#   Gross Cum_world_gross Production_co Run_time  \
# 0
#
#            NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Headstrong New Zealand teen Alex Archer tr...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            5 user          2 critic         6,4                 127
# https://www.imdb.com/title/tt7313888/?ref_=kw_li_i
#   Name       Director          Writer Date_release Country Opening_week_usa  \
# 0  NaN  Jirí Vejdelek  Iva Jestrábová          NaN     NaN              NaN
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Unexpectedly, costume designer Eva has bec...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            0 user          4 critic         6,4                 139
# https://www.imdb.com/title/tt3686270/?ref_=kw_li_i
#   Name     Director       Writer                        Date_release  \
# 0  NaN  Petr Václav  Petr Václav   29 May 2014 (Czech Republic)
#
#
#           Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  Czech Republic             »
#
#
#
#        103 min
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      The Way Out tells a story of a young Roman...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            0 user         14 critic         6,4
#
#   Number_of_who_rated
# 0                 145
# https://www.imdb.com/title/tt2075234/?ref_=kw_li_i
#   Name            Director              Writer               Date_release  \
# 0  NaN  Alessandro Comodin  Alessandro Comodin   Summer of Giacomo
#
#
#    Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  Italian
#    »
#
#    1.78 : 1
#              Color
#
#   Run_time Description Age_rating Metascore Number_of_rewiews  \
# 0      NaN         NaN
#       None            0 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0          9 critic         6,4                 201
# https://www.imdb.com/title/tt1964795/?ref_=kw_li_i
#   Name           Director        Writer                     Date_release  \
# 0  NaN  Giuseppe Piccioni  Marco Lodoli   21 September 2012 (Italy)
#
#
#   Country Opening_week_usa               Budget  Gross Cum_world_gross  \
# 0   Italy
#    $1,728,638           »
#
#
#
#   Production_co Run_time                                        Description  \
# 0           NaN      NaN      The story of a teacher and his students, s...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#       None            0 user         13 critic         6,4
#
#   Number_of_who_rated
# 0                 667
# https://www.imdb.com/title/tt0031745/?ref_=kw_li_i
#   Name       Director         Writer Date_release   Country Opening_week_usa  \
# 0  NaN  Frantisek Cáp  Frantisek Cáp         »
#     See more              NaN
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      This romantic story turns on a stirring in...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            0 user          1 critic         6,4                  25
# https://www.imdb.com/title/tt0962768/?ref_=kw_li_i
#   Name      Director        Writer                      Date_release Country  \
# 0  NaN  Daryl Cloran  Daryl Cloran   10 September 2007 (Canada)
#       Canada
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#              NaN         Color      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Eyelids smeared with black shadow, a teena...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user               NaN         6,4                  55
# https://www.imdb.com/title/tt0804532/?ref_=kw_li_i
#   Name         Director          Writer Date_release  Country  \
# 0  NaN  Salvatore Mereu  Giuseppe Fiori
#   Italian
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0              NaN    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A Sardinian boy torn from his father by fa...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user          4 critic         6,4                 100
# https://www.imdb.com/title/tt1130773/?ref_=kw_li_i
#   Name        Director      Writer                     Date_release Country  \
# 0  NaN  Wen-tang Cheng  Enno Cheng   16 November 2007 (Taiwan)
#       Taiwan
#
#   Opening_week_usa            Budget  Gross Cum_world_gross Production_co  \
# 0
#    $55,935           »
#
#            NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      Taking you back to those heady teenage day...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            2 user          4 critic         6,4
#
#   Number_of_who_rated
# 0                 173
# https://www.imdb.com/title/tt0111354/?ref_=kw_li_i
#   Name        Director          Writer Date_release Country Opening_week_usa  \
# 0  NaN  Michel Khleifi  Michel Khleifi          NaN     NaN              NaN
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A Palestinian boy becomes entranced with a...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            2 user          2 critic         6,4                  88
# https://www.imdb.com/title/tt3585698/?ref_=kw_li_i
#   Name         Director           Writer                    Date_release  \
# 0  NaN  Antonín Kopriva  Antonín Kopriva   Zamek 'Nieskonczonosc'
#
#
#   Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0   Czech
#
#
#              NaN           NaN
#
#   Run_time Description Age_rating Metascore Number_of_rewiews  \
# 0      NaN         NaN
#        NaN               NaN
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN         6,4                   9
# https://www.imdb.com/title/tt5033722/?ref_=kw_li_i
#   Name     Director             Writer                          Date_release  \
# 0  NaN  Dusan Klein  Ladislav Pechácek   Ako básnici cakajú na zázrak
#
#
#   Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0   Czech
#    »
#      NaN             NaN           NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      This time the "poets" are waiting for a mi...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            0 user          5 critic         6,4
#
#   Number_of_who_rated
# 0                  74
# https://www.imdb.com/title/tt0129403/?ref_=kw_li_i
#   Name                    Director              Writer          Date_release  \
# 0  NaN  Nils-Reinhardt Christensen  Anthony Buckeridge   Stompa & Co.
#
#
#      Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  Norwegian
#
#    NaN             NaN           NaN
#
#   Run_time Description Age_rating Metascore Number_of_rewiews  \
# 0      NaN         NaN
#       None            0 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0          1 critic         6,4                 124
# https://www.imdb.com/title/tt0133706/?ref_=kw_li_i
#   Name             Director            Writer        Date_release Country  \
# 0  NaN  Chatrichalerm Yukol  Sorapong Chatree   Daughter 2
#           Thai
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#   Description Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0         NaN
#       None            1 user               NaN
#
#   Imdb_rating Number_of_who_rated
# 0         6,4                  41
# https://www.imdb.com/title/tt2201236/?ref_=kw_li_i
#                                    Name          Director  \
# 0  Ya tebya ne lyublyu (original title)  Pavel Kostomarov
#
#                   Writer                Date_release Country Opening_week_usa  \
# 0  Susanna Barandzhiyeva   7 June 2012 (Russia)
#       Russia             »
#
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      A youth comedy about the tragedy of the fi...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            0 user          1 critic         6,4                  38
# https://www.imdb.com/title/tt0257587/?ref_=kw_li_i
#   Name              Director                  Writer Date_release  Country  \
# 0  NaN  Ismael Rodríguez Jr.  Carlos Enrique Taboada
#   Spanish
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#
#              NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A gang of criminal teens take shelter from...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user               NaN         6,4                   7
# https://www.imdb.com/title/tt0999891/?ref_=kw_li_i
#   Name     Director         Writer               Date_release Country  \
# 0  NaN  Jon Frankel  Siobhan Dunne   27 April 2007 (USA)
#          USA
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#
#         Stereo      NaN
#
#                                          Description Age_rating Metascore  \
# 0      In their third season, the Harlem Hellfigh...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user               NaN         6,4                  25
# https://www.imdb.com/title/tt0232995/?ref_=kw_li_i
#   Name      Director               Writer                      Date_release  \
# 0  NaN  Jirí Svoboda  Ludmila Romportlová   The Mirror for Christine
#
#
#   Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0   Czech              NaN
#    NaN             NaN           NaN
#
#   Run_time Description Age_rating Metascore Number_of_rewiews  \
# 0      NaN         NaN
#        NaN               NaN
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN         6,4                  15
# https://www.imdb.com/title/tt1445787/?ref_=kw_li_i
#   Name      Director      Writer                  Date_release Country  \
# 0  NaN  Joseph Wilka  Mark Lyons   30 December 2008 (USA)
#          USA
#
#   Opening_week_usa               Budget  Gross Cum_world_gross Production_co  \
# 0
#   $1,500
#                »
#
#            NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      On the first Friday of the school year, Pe...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            1 user          1 critic         6,4
#
#   Number_of_who_rated
# 0                  68
# https://www.imdb.com/title/tt5087804/?ref_=kw_li_i
#   Name      Director        Writer              Date_release Country  \
# 0  NaN  Raja Krishna  Raja Krishna   5 May 2016 (India)
#        India
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#
#            DTS      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A 15 year old mute village girl runs away ...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         6,4                  12
