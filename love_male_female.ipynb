# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
# import re
# import json
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import random
from numpy import NaN as nan
import csv

# %%
driver = webdriver.Chrome()

# %%
# f-rated 

driver = webdriver.Chrome()
# all_links = []
links = []
ref = 'https://www.imdb.com/search/keyword/?keywords=love%2Cmale-female-relationship&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=bdc91cb7-0144-4906-b072-b45760c8aa67&pf_rd_r=PXCPH97MT3PHQD6DF4AY&pf_rd_s=right-1&pf_rd_t=15051&pf_rd_i=genre&ref_=kw_ref_key&mode=detail&'
prod = '&title_type=movie&sort=user_rating,desc'
for i in range(21,31,1):
    time.sleep(random.uniform(2,4))
    url = ref + 'page=' + str(i) + prod
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    divs = soup.find('div', {'class':'lister-list'}).find_all('div', {'class':'lister-item mode-detail'})
    for div in divs:
        a = div.find('a').get('href')
        links.append(a)
#     all_links.append(links)

# %%
data_for_all_links = pd.DataFrame([])
all_links_ser = pd.Series(a)
len_list = range(0,len(all_links_ser))
link = 'https://www.imdb.com'

for i in links:
#     data_for_some_links = pd.DataFrame([])
#     for j in i:
#         print(j)
    url = link + i
    print(url)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')

    try:
        data_for_dir = soup.find('div', {'class':'credit_summary_item'})
        a = data_for_dir.find('a')
        director = list(a)[0]
    except AttributeError:
        director = nan
    except IndexError:
        director = nan

    # жанры
    try:
        div = soup.find('div', {'id':'titleStoryLine'}).contents[19]
        gen = div.find_all('a')
        genres = []
        for i in gen:
            genres.append(i.string)
    except AttributeError:
        genres = nan
    except IndexError:
        genres = nan

    # сценарист
    try:
        div = soup.find('div', {'class':'plot_summary'}).contents[5]
        gen = div.find_all('a')
        writer = list(gen[0])[0]
    #     writers = []
    #     for i in gen:
    #         writers.append(i.text)
    except AttributeError:
        writer = nan
    except IndexError:
        writer = nan

    # название    
    try:
        name = soup.find('div', {'class':'originalTitle'}).text
    except AttributeError:
        name = nan
    except IndexError:
        name = nan    

    # дата релиза
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        date_release = data[3]
    except AttributeError:
        date_release = nan
    except IndexError:
        date_release = nan

    # бюджет
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        budget = data[6]
    except AttributeError:
        budget = nan
    except IndexError:
        budget = nan    

    # кассовые сборы в первую неделю (в сша)    
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        opening_weekend_usa = data[7]
    except AttributeError:
        opening_weekend_usa = nan
    except IndexError:
        opening_weekend_usa = nan

    # кассовые сборы в сша    
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        gross_usa = data[8]
    except AttributeError:
        gross_usa = nan
    except IndexError:
        gross_usa = nan    

    # кассовые сборы в мире
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.contents[2]
            data.append(a)
        cumulative_worldwide_gross = data[9]
    except AttributeError:
        cumulative_worldwide_gross = nan
    except IndexError:
        cumulative_worldwide_gross = nan    


    # страна производства
    try:
        div = soup.find('div', {'id':'titleDetails'})
        gen = div.find_all('div', {'class':'txt-block'})
        data = []
        for i in gen:
            a = i.find_all('a')
            data.append(a)
        country = list(data[1][0])[0]
    except AttributeError:
        country = nan
    except IndexError:
        country = nan

    # компания производства
    try:
        production_co = soup.find('div', {'id':'titleDetails'}).contents[37].contents[3].contents[0]
    except IndexError:
        production_co = nan
    except AttributeError:
        production_co = nan


    # описание (синопсис)
    try:
        div = soup.find('div', {'id':'titleStoryLine'})
        gen = div.find_all('div', {'class':'inline canwrap'})
        data = []
        for i in gen:
            a = i.find_all('span')
            data.append(a)
        description = list(data[0][0])[0]
    except IndexError:
        description = nan
    except AttributeError:
        description = nan

    # длительность
    try:
        divs = soup.find('div', {'class':'title_wrapper'}) # для длительности фильма
        run_time = divs.contents[5].contents[3].contents[0]
        # div = divs.find('time', {'datetime':'PT125M'})
        # run_time = div.contents[0].string
    except IndexError:
        run_time = nan
    except AttributeError:
        run_time = nan


    # возрастной рейтинг
    try:
        divs = soup.find('div', {'class':'title_wrapper'}) # для возрастного рейтинга
        div = divs.find('div', {'class':'subtext'})
        age_rating = div.contents[0]
    except IndexError:
        age_rating = nan
    except AttributeError:
        age_rating = nan


    # метаскоре
    try:
        div = soup.find('div', {'class':'titleReviewBarItem'}) # для метаскора (узнать, что такое метаскор)
        meta = div.find_all('span')
        list_for_meta = []
        for i in meta:
            list_for_meta.append(i.string)
        metascore = list_for_meta[0]
    except IndexError:
        metascore = nan
    except AttributeError:
        metascore = nan

    # рейтинг IMdb
    try:
        div = soup.find('div', {'class':'imdbRating'}) # рейтинг IMdb, кол-во отзывов и крит. рецензий
        imdb_rat = div.find_all('span')
        list_for_imdb_rat = []
        for i in imdb_rat:
            list_for_imdb_rat.append(i.string)
        imdb_rating = list_for_imdb_rat[0]
    except IndexError:
        imdb_rating = nan
    except AttributeError:
        imdb_rating = nan


    # количество проголосовавших
    try:
        div = soup.find('div', {'class':'imdbRating'}) # рейтинг IMdb, кол-во отзывов и крит. рецензий
        imdb_rat = div.find_all('span')
        list_for_imdb_rat = []
        for i in imdb_rat:
            list_for_imdb_rat.append(i.string)
        all_who_put_rating = list_for_imdb_rat[3]
    except IndexError:
        all_who_put_rating = nan
    except AttributeError:
        all_who_put_rating = nan    

    # количество тех, кто оставил отзыв
    try:
        div = soup.find('div', {'class':'imdbRating'}) # рейтинг IMdb, кол-во отзывов и крит. рецензий
        imdb_rat = div.find_all('span')
        list_for_imdb_rat = []
        for i in imdb_rat:
            list_for_imdb_rat.append(i.string)
        all_users_who_put_rewiew = list_for_imdb_rat[4]
    except IndexError:
        all_users_who_put_rewiew = nan
    except AttributeError:
        all_users_who_put_rewiew = nan


    # количество критиков, оставивших отзыв
    try:
        div = soup.find('div', {'class':'imdbRating'}) # рейтинг IMdb, кол-во отзывов и крит. рецензий
        imdb_rat = div.find_all('span')
        list_for_imdb_rat = []
        for i in imdb_rat:
            list_for_imdb_rat.append(i.string)
        all_critics_who_put_rewiew = list_for_imdb_rat[5]
    except IndexError:
        all_critics_who_put_rewiew = nan
    except AttributeError:
        all_critics_who_put_rewiew = nan

    # div = soup.find('div', {'class':'titleReviewBarItem titleReviewbarItemBorder'})
    # crit = div.find_all('a')
    # list_for_crit = []
    # for i in crit:
    #     print(i)
    #     list_for_crit.append(i.string)
    # all_new_users = list_for_crit[0]
    # all_new_critic = list_for_crit[1]


    data = (
        [name, director,writer,
         date_release, country, opening_weekend_usa, budget, gross_usa, 
         cumulative_worldwide_gross, production_co, 
         run_time, description,age_rating,
         metascore, all_users_who_put_rewiew,
         all_critics_who_put_rewiew, imdb_rating, all_who_put_rating
        ]
    )

    col = (
        ['Name','Director','Writer','Date_release', 
         'Country',
         'Opening_week_usa',
         'Budget', 'Gross',
         'Cum_world_gross','Production_co',
         'Run_time','Description',
         'Age_rating',
         'Metascore','Number_of_rewiews',
         'Number_of_critics','Imdb_rating','Number_of_who_rated']
    )

    total_data = (
    (pd.DataFrame(
    data,col
    )).transpose()
    )

    print(total_data)

    data_for_all_links = data_for_all_links.append(total_data)
    data_for_some_links = (data_for_all_links.append(total_data)).drop_duplicates()

    data_for_all_links.to_excel('C:/Users/1/Documents/Project/Data/love_male_female_low.xlsx', index = False)

#         total_data = total_data.append(total_data)

#         data_for_some_links = (data_for_some_links.append(total_data)).drop_duplicates()

#     data_for_all_links = data_for_all_links.append(data_for_some_links)
# Out:
# https://www.imdb.com/title/tt0120894/?ref_=kw_li_i
#                                         Name       Director        Writer  \
# 0  The Wisdom of Crocodiles (original title)  Po-Chih Leong  Paul Hoffman
#
#                   Date_release  Country  Opening_week_usa            Budget  \
# 0   Мудрость крокодилов
#         English   $54,836           $25,648
#
#   Gross Cum_world_gross Production_co  \
# 0
#             »
#              NaN
#
#                                             Run_time  \
# 0
#                         1h 38min
#             ...
#
#                                          Description  \
# 0      Steven is multi-talented, handsome, and a ...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             58           65 user         45 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,2               5 548
# https://www.imdb.com/title/tt0057225/?ref_=kw_li_i
#                                 Name         Director          Writer  \
# 0  Kings of the Sun (original title)  J. Lee Thompson  Elliott Arnold
#
#                 Date_release  Country Opening_week_usa Budget Gross  \
# 0   Los reyes del sol
#         English             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#        108 min        |
#
#                                          Description Age_rating Metascore  \
# 0      In order to flee from powerful enemies, yo...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           50 user         15 critic         6,2               1 589
# https://www.imdb.com/title/tt0047365/?ref_=kw_li_i
#                               Name        Director          Writer  \
# 0  Prince Valiant (original title)  Henry Hathaway  Dudley Nichols
#
#             Date_release  Country Opening_week_usa           Budget  Gross  \
# 0   Prins Valiant
#         English
#    $3,373           »
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Young Prince Valiant, son of the exiled Ki...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           42 user         23 critic         6,2               2 274
# https://www.imdb.com/title/tt0138590/?ref_=kw_li_i
#                                               Name      Director      Writer  \
# 0  The Man with Rain in His Shoes (original title)  Maria Ripoll  Rafa Russo
#
#                           Date_release  Country     Opening_week_usa  \
# 0   Человек с дождем в ботинках
#         English   $7,162,884
#
#               Budget Gross Cum_world_gross Production_co  \
# 0   $279,757
#             »
#              NaN
#
#                                             Run_time  \
# 0
#                         1h 31min
#             ...
#
#                                          Description  \
# 0      Victor, an out of work actor, tries to sto...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#           None           42 user         31 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,2               2 353
# https://www.imdb.com/title/tt0085994/?ref_=kw_li_i
#                               Name           Director          Writer  \
# 0  Nate and Hayes (original title)  Ferdinand Fairfax  Lloyd Phillips
#
#              Date_release  Country     Opening_week_usa       Budget  \
# 0   Savage Islands
#         English   $1,963,756           $815,160,
#
#
#                  Gross Cum_world_gross Production_co Run_time  \
# 0   $1,963,756
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      It's the late nineteenth century in the So...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           24 user          9 critic         6,2               1 820
# https://www.imdb.com/title/tt0301684/?ref_=kw_li_i
#                                                 Name       Director  \
# 0  Once Upon a Time in the Midlands (original title)  Shane Meadows
#
#         Writer                 Date_release Country Opening_week_usa  \
# 0  Paul Fraser   6 September 2002 (UK)
#           UK        $21,475,
#
#
#                       Budget              Gross    Cum_world_gross  \
# 0  GBP1,950,000
#                $172,564           $544,512
#
#   Production_co                                           Run_time  \
# 0      FilmFour
#                         1h 44min
#             ...
#
#                                          Description  \
# 0      Originally from the Midlands, Jimmy is cur...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             56           42 user         42 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,2               4 049
# https://www.imdb.com/title/tt0104550/?ref_=kw_li_i
#                            Name             Director        Writer  \
# 0  Jersey Girl (original title)  David Burton Morris  Gina Wendkos
#
#                  Date_release  Country Opening_week_usa Budget Gross  \
# 0   Принц из Нью-Йорка
#         English
#    »
#
#
#
#   Cum_world_gross Production_co  \
# 0   1.85 : 1
#                NaN
#
#                                             Run_time  \
# 0
#                         1h 35min
#             ...
#
#                                          Description  \
# 0      Sal is a wealthy and triumphant yuppie who...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#           None           23 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0          1 critic         6,2               1 391
# https://www.imdb.com/title/tt0079123/?ref_=kw_li_i
#                              Name     Director       Writer  \
# 0  The Europeans (original title)  James Ivory  Henry James
#
#            Date_release Country Opening_week_usa Budget Gross Cum_world_gross  \
# 0   July 1979 (UK)
#           UK             »
#
#
#
#
#
#   Production_co Run_time                                        Description  \
# 0           NaN        |      It's the mid-nineteenth century. Adult sib...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#         64            7 user         14 critic         6,2
#
#   Number_of_who_rated
# 0                 751
# https://www.imdb.com/title/tt0070794/?ref_=kw_li_i
#                                             Name    Director       Writer  \
# 0  The Thief Who Came to Dinner (original title)  Bud Yorkin  Walter Hill
#
#                Date_release  Country Opening_week_usa Budget Gross  \
# 0   A sakkozó tolvaj
#         English
#    »
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Bored and somewhat fed up with the open co...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           20 user          7 critic         6,2                 811
# https://www.imdb.com/title/tt0469233/?ref_=kw_li_i
#                                         Name          Director  \
# 0  Französisch für Anfänger (original title)  Christian Ditter
#
#              Writer                 Date_release  Country Opening_week_usa  \
# 0  Christian Ditter   26 July 2007 (Russia)
#       Germany
#
#
#                 Budget  Gross Cum_world_gross Production_co  \
# 0   $2,054,209           »
#
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 38min
#             ...
#
#                                          Description  \
# 0      Échange tells the story of HENRIK, who tak...
#
#                       Age_rating Metascore Number_of_rewiews  \
# 0
#                     12+
#           None            2 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         10 critic         6,2                 914
# https://www.imdb.com/title/tt0042677/?ref_=kw_li_i
#                                  Name      Director          Writer  \
# 0  A Life of Her Own (original title)  George Cukor  Isobel Lennart
#
#                    Date_release  Country Opening_week_usa Budget Gross  \
# 0   Её собственная жизнь
#         English             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#        108 min        |
#
#                                          Description Age_rating Metascore  \
# 0      Small town Kansas girl, Lily James, is the...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           32 user          9 critic         6,2                 780
# https://www.imdb.com/title/tt0038505/?ref_=kw_li_i
#   Name        Director            Writer              Date_release  Country  \
# 0  NaN  Edward Buzzell  Dorothy Kingsley   Que siga la boda
#         English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#
#        106 min      NaN
#
#                                          Description Age_rating Metascore  \
# 0      The "Morning Star" is in trouble: J.B. All...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           17 user         13 critic         6,2                 621
# https://www.imdb.com/title/tt0246134/?ref_=kw_li_i
#                            Name        Director         Writer  \
# 0  Lucky Break (original title)  Peter Cattaneo  Ronan Bennett
#
#                       Date_release Country Opening_week_usa  \
# 0   14 February 2002 (Russia)
#           UK         $7,495,
#
#
#                     Budget             Gross      Cum_world_gross  \
# 0  $6,000,000
#                $54,606           $2,572,403
#
#   Production_co                                           Run_time  \
# 0      FilmFour
#                         1h 47min
#             ...
#
#                                          Description  \
# 0      Half-way through his 12-year prison senten...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#             48           32 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         48 critic         6,2               2 079
# https://www.imdb.com/title/tt0114846/?ref_=kw_li_i
#   Name     Director         Writer              Date_release  Country  \
# 0  NaN  Mark Peploe  Joseph Conrad   Fuga Para o Amor
#         English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#
#            NaN      NaN
#
#                                          Description  \
# 0      Axel Heyst lives on a secluded island near...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#           None           13 user          4 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,2                 420
# https://www.imdb.com/title/tt0039312/?ref_=kw_li_i
#   Name     Director          Writer                 Date_release  Country  \
# 0  NaN  Jack Conway  Leonhard Frank   La femme de l'autre
#         English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#
#         91 min      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Shortly after WWII, flashbacks tell the st...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           23 user          4 critic         6,2                 557
# https://www.imdb.com/title/tt1327196/?ref_=kw_li_i
#   Name     Director       Writer      Date_release Country Opening_week_usa  \
# 0  NaN  Jill Jaress  Jill Jaress   2014 (USA)
#          USA
#
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0   »
#      NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Six lives change when two strangers wake u...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            6 user               NaN         6,2                  58
# https://www.imdb.com/title/tt0210149/?ref_=kw_li_i
#                         Name      Director       Writer   Date_release  \
# 0  Lakeboat (original title)  Joe Mantegna  David Mamet   Лодка
#
#
#    Country Opening_week_usa           Budget  Gross Cum_world_gross  \
# 0  English
#    $5,159           »
#
#
#
#   Production_co                                           Run_time  \
# 0           NaN
#                         1h 38min
#             ...
#
#                                          Description  \
# 0      Coming-of-age tale set aboard a freighter ...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             59           19 user         22 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,2                 599
# https://www.imdb.com/title/tt0025119/?ref_=kw_li_i
#   Name          Director          Writer         Date_release  Country  \
# 0  NaN  William Dieterle  Charles Kenyon   Ave de Fogo
#         English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#
#            NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Herman Brandt, a handsome but overly conce...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           11 user          4 critic         6,2                 209
# https://www.imdb.com/title/tt0206608/?ref_=kw_li_i
#   Name     Director      Writer          Date_release Country  \
# 0  NaN  Jan Schütte  Klaus Pohl   The Farewell
#         German
#
#   Opening_week_usa            Budget  Gross Cum_world_gross Production_co  \
# 0
#    $10,952           »
#
#            NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      It is one of the last days of an exception...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0        58            5 user         25 critic         6,2
#
#   Number_of_who_rated
# 0                 164
# https://www.imdb.com/title/tt0116932/?ref_=kw_li_i
#   Name        Director        Writer        Date_release Country  \
# 0  NaN  Marion Vernoux  Dodine Herry   Amor, Etc.
#         French
#
#   Opening_week_usa Budget           Gross Cum_world_gross Production_co  \
# 0
#
#    2.35 : 1
#                  NaN           NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      A triangle: love, obsession, and choice. P...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            7 user          8 critic         6,2
#
#   Number_of_who_rated
# 0                 596
# https://www.imdb.com/title/tt0181396/?ref_=kw_li_i
#                                    Name          Director  \
# 0  Come te nessuno mai (original title)  Gabriele Muccino
#
#                 Writer                       Date_release  Country  \
# 0  Marco Valerio Fusco   Но навсегда в моей памяти
#         Italian
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#
#         88 min        |
#
#                                          Description Age_rating Metascore  \
# 0      Silvio is sixteen and is more interested i...
#         59
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            7 user          8 critic         6,2               1 466
# https://www.imdb.com/title/tt0178704/?ref_=kw_li_i
#   Name          Director        Writer                   Date_release  \
# 0  NaN  Jerry Ciccoritti  Semi Chellas   Zanim do tego dojdzie
#
#
#    Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  English
#    »
#
#
#            NaN
#
#   Run_time                                        Description  \
# 0      NaN      In Toronto, two criminals enter a café one...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#           None           11 user          4 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,2                 454
# https://www.imdb.com/title/tt0094822/?ref_=kw_li_i
#   Name       Director              Writer         Date_release  Country  \
# 0  NaN  Rafael Moleón  Agustín Díaz Yanes   Amor mátame
#         Spanish
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Antonio dotes on his mute brother and prom...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user          1 critic         6,2                 245
# https://www.imdb.com/title/tt0121442/?ref_=kw_li_i
#   Name      Director          Writer                          Date_release  \
# 0  NaN  Stijn Coninx  Alain Berliner   23 February 1990 (Netherlands)
#
#
#    Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  Belgium
#    »
#
#
#            NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      Due to a mistake Placide Smellekens appear...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            2 user          1 critic         6,2
#
#   Number_of_who_rated
# 0               2 025
# https://www.imdb.com/title/tt0024421/?ref_=kw_li_i
#   Name      Director               Writer           Date_release  Country  \
# 0  NaN  George Cukor  W. Somerset Maugham   Haute société
#         English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#
#    1.37 : 1
#                NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      American heiress Pearl Saunders marries Lo...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           19 user         10 critic         6,2                 559
# https://www.imdb.com/title/tt0052323/?ref_=kw_li_i
#   Name    Director      Writer                           Date_release  \
# 0  NaN  Muriel Box  Muriel Box   A Verdade Acerca das Mulheres
#
#
#    Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  English
#    »
#
#    1.75 : 1
#                NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      A man recalls his relationships with the w...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            3 user          1 critic         6,2
#
#   Number_of_who_rated
# 0                 143
# https://www.imdb.com/title/tt1513760/?ref_=kw_li_i
#   Name        Director          Writer                 Date_release Country  \
# 0  NaN  Brent Florence  Brent Florence   2 November 2011 (USA)
#          USA
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A team of investigative documentarians set...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            8 user          2 critic         6,2                 131
# https://www.imdb.com/title/tt0028677/?ref_=kw_li_i
#   Name      Director        Writer Date_release Country Opening_week_usa  \
# 0  NaN  Arthur Lubin  Herman Boxer          NaN     NaN              NaN
#
#   Budget Gross Cum_world_gross Production_co Run_time Description Age_rating  \
# 0    NaN   NaN             NaN           NaN      NaN         NaN
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            5 user          1 critic         6,2
#
#   Number_of_who_rated
# 0                 104
# https://www.imdb.com/title/tt0296686/?ref_=kw_li_i
#   Name       Director       Writer Date_release Country Opening_week_usa  \
# 0  NaN  Ivan Calbérac  Eric Assous
#   French
#
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0   »
#
#
#         Stereo      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Irène is a beautiful girl working in Paris...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            2 user          4 critic         6,2                 549
# https://www.imdb.com/title/tt1210341/?ref_=kw_li_i
#   Name       Director          Writer     Date_release   Country  \
# 0  NaN  Mac Alejandre  Irma Dimaranan   Amnesia
#         Filipino
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#      NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A story about a wife's struggle for his hu...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            3 user          1 critic         6,2                  48
# https://www.imdb.com/title/tt0091685/?ref_=kw_li_i
#   Name       Director             Writer                     Date_release  \
# 0  NaN  Guido Pieters  Herman Heijermans   Esperança de benedicció
#
#
#   Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0   Dutch             »
#
#
#
#         93 min
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      Young Barend is worried about the safety o...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            3 user          2 critic         6,2
#
#   Number_of_who_rated
# 0                 392
# https://www.imdb.com/title/tt0815462/?ref_=kw_li_i
#   Name       Director         Writer                Date_release Country  \
# 0  NaN  Roser Aguilar  Roser Aguilar   7 March 2008 (Spain)
#        Spain
#
#   Opening_week_usa             Budget  Gross Cum_world_gross Production_co  \
# 0
#    $401,227           »
#
#            NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      Raquel and Tomas are an average young coup...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            0 user          5 critic         6,2
#
#   Number_of_who_rated
# 0                 241
# https://www.imdb.com/title/tt0027231/?ref_=kw_li_i
#   Name      Director        Writer            Date_release  Country  \
# 0  NaN  Joseph Green  Joseph Green   Sreći u susret
#         Yiddish
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#
#            NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Director Green returned to his native Pola...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            6 user          1 critic         6,2                 140
# https://www.imdb.com/title/tt0118610/?ref_=kw_li_i
#   Name                Director                  Writer         Date_release  \
# 0  NaN  Yolanda García Serrano  Yolanda García Serrano   Love of Man
#
#
#    Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  Spanish
#    »
#
#    1.85 : 1
#              Color
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      In 1990s Spain, the strong friendship betw...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None           12 user          5 critic         6,2
#
#   Number_of_who_rated
# 0                 487
# https://www.imdb.com/title/tt0074744/?ref_=kw_li_i
#   Name        Director         Writer         Date_release    Country  \
# 0  NaN  Márta Mészáros  Gyula Hernádi   Nine Months
#         Hungarian
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#
#    1.37 : 1
#                NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A village-girl (Juli Kovács) arrives in th...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         6,2                  71
# https://www.imdb.com/title/tt0428303/?ref_=kw_li_i
#                       Name          Director            Writer  \
# 0  Cavite (original title)  Neill Dela Llana  Neill Dela Llana
#
#                           Date_release      Country Opening_week_usa  \
# 0   28 January 2005 (Netherlands)
#       Philippines        $12,726,
#
#
#                 Budget             Gross   Cum_world_gross   Production_co  \
# 0  $7,000
#                $70,071           $70,071           Gorilla Films
#
#   Run_time                                        Description Age_rating  \
# 0        |      Adam, a security guard, travels from Calif...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0        64           35 user         36 critic         6,2
#
#   Number_of_who_rated
# 0                 607
# https://www.imdb.com/title/tt0100435/?ref_=kw_li_i
#   Name         Director            Writer    Date_release  Country  \
# 0  NaN  Michele Placido  Sandro Petraglia   Tomato
#         Italian
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#
#              NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Kwaku, a young African medical student, ar...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         6,2                  38
# https://www.imdb.com/title/tt0015724/?ref_=kw_li_i
#   Name           Director             Writer               Date_release  \
# 0  NaN  Eva López Sánchez  Eva López Sánchez   Lady of the Night
#
#
#    Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  Spanish
#    »
#
#    1.33 : 1
#                NaN
#
#   Run_time Description Age_rating Metascore Number_of_rewiews  \
# 0      NaN         NaN
#        NaN               NaN
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN         6,2                  20
# https://www.imdb.com/title/tt1429451/?ref_=kw_li_i
#   Name   Director        Writer         Date_release       Country  \
# 0  NaN  Anna Luif  Elke Rössler   Fou d'amour
#         Swiss German
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0              NaN
#    NaN             NaN           NaN      NaN
#
#   Description Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0         NaN
#       None            0 user          3 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,2                  48
# https://www.imdb.com/title/tt0129885/?ref_=kw_li_i
#   Name           Director             Writer      Date_release Country  \
# 0  NaN  Sophie Dia Pegrum  Sophie Dia Pegrum   1997 (USA)
#          USA
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#
#          Dolby      NaN
#
#                                          Description Age_rating Metascore  \
# 0      The story of Dogstar, a reclusive artist, ...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user          2 critic         6,2                  33
# https://www.imdb.com/title/tt0208348/?ref_=kw_li_i
#   Name      Director        Writer                         Date_release  \
# 0  NaN  Hélène Angel  Hélène Angel   Skin of Man, Heart of Beast
#
#
#   Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  French
#
#
#              NaN           NaN
#
#   Run_time Description Age_rating Metascore Number_of_rewiews  \
# 0      NaN         NaN
#         64           15 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         17 critic         6,2                 237
# https://www.imdb.com/title/tt0141762/?ref_=kw_li_i
#   Name        Director          Writer            Date_release  Country  \
# 0  NaN  Anssi Mänttäri  Anssi Mänttäri   En kärleksfilm
#         Finnish
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#              NaN         Color      NaN
#
#   Description Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0         NaN
#        NaN               NaN               NaN
#
#   Imdb_rating Number_of_who_rated
# 0         6,2                  40
# https://www.imdb.com/title/tt0082058/?ref_=kw_li_i
#                            Name        Director          Writer  \
# 0  Belyy voron (original title)  Valeri Lonskoy  Valeri Lonskoy
#
#              Date_release  Country Opening_week_usa Budget Gross  \
# 0   The White Crow
#         Russian
#
#    NaN
#
#   Cum_world_gross Production_co Run_time Description Age_rating Metascore  \
# 0             NaN           NaN        |         NaN
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         6,2                  17
# https://www.imdb.com/title/tt0784145/?ref_=kw_li_i
#                                    Name       Director           Writer  \
# 0  Kaze wo mita shônen (original title)  Kazuki Ohmori  Izuru Narushima
#
#                          Date_release   Country Opening_week_usa Budget Gross  \
# 0   Malchik kotory videl veter
#         Japanese
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0   1.78 : 1
#                NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      A boy has a powerful gift, a war hungery g...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user          2 critic         6,2                 171
# https://www.imdb.com/title/tt0028168/?ref_=kw_li_i
#   Name       Director       Writer Date_release Country Opening_week_usa  \
# 0  NaN  Victor Janson  H.W. Becker          NaN     NaN              NaN
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0    NaN   NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Gusti Aigner and Franz Lenhardt are in lov...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         6,2                   6
# https://www.imdb.com/title/tt0035505/?ref_=kw_li_i
#   Name        Director         Writer Date_release Country Opening_week_usa  \
# 0  NaN  Valentin Vaala  Yrjö Kivimies          NaN     NaN              NaN
#
#   Budget Gross Cum_world_gross Production_co Run_time Description Age_rating  \
# 0    NaN   NaN             NaN           NaN      NaN         NaN
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None            1 user               NaN         6,2
#
#   Number_of_who_rated
# 0                  55
# https://www.imdb.com/title/tt0099422/?ref_=kw_li_i
#                           Name       Director         Writer  \
# 0  Dick Tracy (original title)  Warren Beatty  Chester Gould
#
#          Date_release  Country       Opening_week_usa          Budget  \
# 0   Дик Трэйси
#         English   $103,738,726           $22,543,911,
#
#
#                    Gross Cum_world_gross Production_co Run_time  \
# 0   $162,738,726
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      All Tess Trueheart wants is to settle down...
#         68
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0          187 user         98 critic         6,1              55 110
# https://www.imdb.com/title/tt0090142/?ref_=kw_li_i
#                          Name    Director     Writer  \
# 0  Teen Wolf (original title)  Rod Daniel  Jeph Loeb
#
#                Date_release  Country      Opening_week_usa  \
# 0   Lobo adolescente
#         English   $33,086,611
#
#                  Budget Gross Cum_world_gross Production_co Run_time  \
# 0   $33,086,611
#             »
#              NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Meet Scott Howard, a struggling high schoo...
#         25
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0          135 user         84 critic         6,1              43 527
# https://www.imdb.com/title/tt0085811/?ref_=kw_li_i
#                      Name     Director            Writer  \
# 0  Krull (original title)  Peter Yates  Stanford Sherman
#
#                Date_release  Country      Opening_week_usa         Budget  \
# 0   Dragons of Krull
#         English   $16,916,617           $5,469,415,
#
#
#                   Gross Cum_world_gross Production_co Run_time  \
# 0   $16,916,617
#            NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      From the sky will come the Black Fortress....
#         45
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0          200 user         90 critic         6,1              28 904
# https://www.imdb.com/title/tt0313737/?ref_=kw_li_i
#                                 Name       Director         Writer  \
# 0  Two Weeks Notice (original title)  Marc Lawrence  Marc Lawrence
#
#                       Date_release Country Opening_week_usa  \
# 0   27 February 2003 (Russia)
#          USA    $14,328,494,
#
#
#                      Budget                 Gross        Cum_world_gross  \
# 0  $60,000,000
#                $93,354,851           $199,043,242
#
#                 Production_co  \
# 0   Castle Rock Entertainment
#
#                                             Run_time  \
# 0
#                         1h 41min
#             ...
#
#                                          Description  \
# 0      Harvard educated lawyer Lucy Kelson, follo...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#             42          285 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0        111 critic         6,1             101 795
# https://www.imdb.com/title/tt0109369/?ref_=kw_li_i
#                             Name         Director           Writer  \
# 0  Camp Nowhere (original title)  Jonathan Prince  Andrew Kurtzman
#
#                 Date_release  Country      Opening_week_usa  \
# 0   Затерянный лагерь
#         English   $10,475,705
#
#                  Budget Gross Cum_world_gross Production_co  \
# 0   $10,475,705
#             »
#              NaN
#
#                                             Run_time  \
# 0
#                         1h 36min
#             ...
#
#                                          Description  \
# 0      Morris "Mud" Himmel has a problem. His par...
#
#                      Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     PG
#           None           37 user         10 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,1               8 419
# https://www.imdb.com/title/tt0075265/?ref_=kw_li_i
#                               Name       Director              Writer  \
# 0  A Star Is Born (original title)  Frank Pierson  John Gregory Dunne
#
#               Date_release  Country      Opening_week_usa  \
# 0   Звезда родилась
#         English   $80,000,000
#
#                  Budget Gross Cum_world_gross Production_co Run_time  \
# 0   $80,000,000
#             »
#              NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Talented rock star John Norman Howard has ...
#         59
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           94 user         47 critic         6,1               9 303
# https://www.imdb.com/title/tt0287963/?ref_=kw_li_i
#                                Name              Director  \
# 0  Choses secrètes (original title)  Jean-Claude Brisseau
#
#                  Writer            Date_release Country   Opening_week_usa  \
# 0  Jean-Claude Brisseau   Тайные страсти
#         French   $234,255
#
#               Budget Gross Cum_world_gross Production_co Run_time  \
# 0   $105,090
#             »
#              NaN        |
#
#                                          Description Age_rating Metascore  \
# 0      Two young women find themselves struggling...
#         55
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           30 user         61 critic         6,1               4 405
# https://www.imdb.com/title/tt0076868/?ref_=kw_li_i
#                          Name     Director       Writer       Date_release  \
# 0  Valentino (original title)  Ken Russell  Ken Russell   Валентино
#
#
#    Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  English             »
#
#
#
#        128 min
#
#   Run_time                                        Description Age_rating  \
# 0        |      In 1926, the tragic and untimely death of ...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0      None           33 user         39 critic         6,1
#
#   Number_of_who_rated
# 0               1 586
# https://www.imdb.com/title/tt0800240/?ref_=kw_li_i
#                          Name            Director        Writer  \
# 0  Deception (original title)  Marcel Langenegger  Mark Bomback
#
#                Date_release  Country     Opening_week_usa         Budget  \
# 0   Список контактов
#         English   $4,598,506           $2,312,146,
#
#
#                   Gross Cum_world_gross Production_co  \
# 0   $17,772,506
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 47min
#             ...
#
#                                          Description  \
# 0      Cat and mouse. Jonathan McQuarry is an aud...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             31          112 user         99 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,1              36 863
# https://www.imdb.com/title/tt0236784/?ref_=kw_li_i
#                                     Name      Director         Writer  \
# 0  The Tailor of Panama (original title)  John Boorman  John le Carré
#
#                 Date_release Country Opening_week_usa  \
# 0   30 March 2001 (USA)
#          USA     $1,837,068,
#
#
#                      Budget                 Gross       Cum_world_gross  \
# 0  $21,000,000
#                $13,729,742           $28,008,462
#
#         Production_co                                           Run_time  \
# 0   Columbia Pictures
#                         1h 49min
#             ...
#
#                                          Description  \
# 0      Women have been MI.6. agent Andy Osnard's ...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             66          214 user         67 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,1              27 053
# https://www.imdb.com/title/tt0179626/?ref_=kw_li_i
#                           Name       Director         Writer Date_release  \
# 0  15 Minutes (original title)  John Herzfeld  John Herzfeld          NaN
#
#   Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0     NaN              NaN    NaN   NaN             NaN           NaN
#
#                                            Run_time Description  \
# 0
#                         2h
#                              NaN
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             34          264 user        153 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,1              47 312
# https://www.imdb.com/title/tt0112887/?ref_=kw_li_i
#                                    Name     Director       Writer  \
# 0  The Doom Generation (original title)  Gregg Araki  Gregg Araki
#
#                     Date_release  Country   Opening_week_usa  \
# 0   Поколение игры 'Doom'
#         English   $284,785
#
#               Budget Gross Cum_world_gross Production_co  \
# 0   $284,785
#             »
#              NaN
#
#                                             Run_time  \
# 0
#                         1h 23min
#             ...
#
#                                          Description  \
# 0      Jordan White and Amy Blue, two troubled te...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             48          199 user         53 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,1              13 344
# https://www.imdb.com/title/tt0082951/?ref_=kw_li_i
#                            Name     Director         Writer  \
# 0  The Prowler (original title)  Joseph Zito  Glenn Leopold
#
#                 Date_release  Country Opening_week_usa Budget Gross  \
# 0   Rosemary's Killer
#         English             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#         89 min        |
#
#                                          Description Age_rating Metascore  \
# 0      The film begins with the return home of a ...
#         45
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0          127 user         87 critic         6,1               8 798
# https://www.imdb.com/title/tt1046997/?ref_=kw_li_i
#                                    Name   Director         Writer  \
# 0  Miracle at St. Anna (original title)  Spike Lee  James McBride
#
#                     Date_release Country Opening_week_usa  \
# 0   26 September 2008 (USA)
#        Italy     $3,477,996,
#
#
#                      Budget                Gross      Cum_world_gross  \
# 0  $45,000,000
#                $7,919,117           $9,333,654
#
#                   Production_co  \
# 0   40 Acres & A Mule Filmworks
#
#                                             Run_time  \
# 0
#                         2h 40min
#             ...
#
#                                          Description  \
# 0      Christmas, 1983. A New York postal clerk, ...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             37          193 user        150 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,1              17 471
# https://www.imdb.com/title/tt0099747/?ref_=kw_li_i
#                       Name        Director         Writer  \
# 0  Havana (original title)  Sydney Pollack  Judith Rascoe
#
#                    Date_release Country Opening_week_usa  \
# 0   14 December 1990 (USA)
#          USA     $2,175,360,
#
#
#                      Budget                Gross      Cum_world_gross  \
# 0  $40,000,000
#                $9,243,140           $9,645,440
#
#          Production_co                                           Run_time  \
# 0   Mirage Enterprises
#                         2h 24min
#             ...
#
#                                          Description  \
# 0      Cuba, December 1958: The professional gamb...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#           None           49 user         19 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,1               6 841
# https://www.imdb.com/title/tt0348505/?ref_=kw_li_i
#                       Name         Director           Writer  \
# 0  Asylum (original title)  David Mackenzie  Patrick McGrath
#
#                   Date_release Country   Opening_week_usa      Budget  \
# 0   9 September 2005 (UK)
#           UK   $375,403           $36,272,
#
#
#                  Gross Cum_world_gross Production_co  \
# 0   $2,788,033
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 39min
#             ...
#
#                                          Description  \
# 0      In the 1950s, the psychiatrist Max Raphael...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             51           56 user         83 critic
#
#   Imdb_rating Number_of_who_rated
# 0         6,1               4 688
# https://www.imdb.com/title/tt0037175/?ref_=kw_li_i
#   Name              Director        Writer         Date_release  Country  \
# 0  NaN  H. Bruce Humberstone  Robert Ellis   Pin-Up Girl
#         English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#
#         84 min      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Glamorous Lorry Jones, the toast of a Miss...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           19 user         10 critic         6,1                 644
# https://www.imdb.com/title/tt0104695/?ref_=kw_li_i
#                              Name        Director         Writer  \
# 0  Leap of Faith (original title)  Richard Pearce  Janus Cercone
#
#         Date_release  Country      Opening_week_usa                Budget  \
# 0   Сила веры
#         English   $23,369,283           $23,369,283
#
#   Gross Cum_world_gross Production_co  \
# 0
#             »
#              NaN
#
#                                             Run_time  \
# 0
#                         1h 48min
#             ...
#
#                                          Description  \
# 0      Jonas is a fraudulent faith healer, who us...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#           None           77 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         17 critic         6,1              11 746
# https://www.imdb.com/title/tt0118556/?ref_=kw_li_i
#                                 Name       Director         Writer  \
# 0  Addicted to Love (original title)  Griffin Dunne  Robert Gordon
#
#            Date_release  Country      Opening_week_usa                Budget  \
# 0   Дурман любви
#         English   $34,673,095           $34,673,095
#
#   Gross Cum_world_gross Production_co  \
# 0
#             »
#              NaN
#
#                                             Run_time  \
# 0
#                         1h 40min
#             ...
#
#                                          Description  \
# 0      Good-natured astronomer Sam is devastated ...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# ...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         5,0                   9
# https://www.imdb.com/title/tt0267248/?ref_=kw_li_i
#                        Name        Director          Writer  \
# 0  Abandon (original title)  Stephen Gaghan  Stephen Gaghan
#
#                  Date_release Country Opening_week_usa  \
# 0   3 July 2003 (Russia)
#          USA     $5,064,077,
#
#
#                      Budget                 Gross       Cum_world_gross  \
# 0  $25,000,000
#                $10,727,683           $12,302,219
#
#          Production_co                                           Run_time  \
# 0   Paramount Pictures
#                         1h 39min
#             ...
#
#                                          Description  \
# 0      A senior at an elite college, already unde...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#             36          165 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         73 critic         4,9               8 998
# https://www.imdb.com/title/tt0265087/?ref_=kw_li_i
#                             Name    Director          Writer  \
# 0  Black Knight (original title)  Gil Junger  Darryl Quarles
#
#             Date_release  Country      Opening_week_usa          Budget  \
# 0   Чeрный рыцарь
#         English   $33,426,971           $11,102,948,
#
#
#                   Gross Cum_world_gross Production_co  \
# 0   $39,976,235
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 35min
#             ...
#
#                                          Description  \
# 0      This is the story an amusement park employ...
#
#                       Age_rating Metascore Number_of_rewiews  \
# 0
#                     12+
#             32          169 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         49 critic         4,9              36 654
# https://www.imdb.com/title/tt0116606/?ref_=kw_li_i
#                             Name        Director          Writer  \
# 0  If Lucy Fell (original title)  Eric Schaeffer  Eric Schaeffer
#
#                Date_release  Country     Opening_week_usa         Budget  \
# 0   Если Люси упадет
#         English   $2,420,162           $1,308,088,
#
#
#                  Gross Cum_world_gross Production_co  \
# 0   $2,420,162
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 32min
#             ...
#
#                                          Description  \
# 0      Joe and Lucy are roommates and best friend...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#           None           44 user         25 critic
#
#   Imdb_rating Number_of_who_rated
# 0         4,9               3 707
# https://www.imdb.com/title/tt0172627/?ref_=kw_li_i
#                           Name           Director         Writer  \
# 0  Body Shots (original title)  Michael Cristofer  David McKenna
#
#                     Date_release Country   Opening_week_usa       Budget  \
# 0   21 January 2000 (Spain)
#          USA   $752,122           $488,342,
#
#
#                Gross Cum_world_gross Production_co  \
# 0   $752,122
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 46min
#             ...
#
#                                          Description  \
# 0      Four hip women get ready for Friday night ...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#             36           70 user         53 critic
#
#   Imdb_rating Number_of_who_rated
# 0         4,9               5 164
# https://www.imdb.com/title/tt0118772/?ref_=kw_li_i
#                            Name          Director             Writer  \
# 0  Breaking Up (original title)  Robert Greenwald  Michael Cristofer
#
#                Date_release  Country  Opening_week_usa            Budget  \
# 0   На грани разрыва
#         English   $11,690           $11,690
#
#   Gross Cum_world_gross Production_co  \
# 0
#             »
#              NaN
#
#                                             Run_time  \
# 0
#                         1h 30min
#             ...
#
#                                          Description  \
# 0      Monica teaches, Steve's a photographer. Th...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#           None           30 user         11 critic
#
#   Imdb_rating Number_of_who_rated
# 0         4,9               2 675
# https://www.imdb.com/title/tt0330691/?ref_=kw_li_i
#                           Name       Director         Writer   Date_release  \
# 0  Il cartaio (original title)  Dario Argento  Dario Argento   Игрок
#
#
#    Country Opening_week_usa               Budget  Gross Cum_world_gross  \
# 0  Italian
#    $3,368,452           »
#
#
#
#   Production_co Run_time                                        Description  \
# 0           NaN        |      In Rome, after the abduction of a British ...
#
#   Age_rating Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0
#         48           69 user         99 critic         4,9
#
#   Number_of_who_rated
# 0               4 799
# https://www.imdb.com/title/tt0402127/?ref_=kw_li_i
#                             Name        Director             Writer  \
# 0  The Defender (original title)  Dolph Lundgren  Douglas W. Miller
#
#                   Date_release Country Opening_week_usa  \
# 0   1 March 2005 (Russia)
#          USA
#
#
#                     Budget  Gross Cum_world_gross Production_co  \
# 0  $6,000,000
#                »
#
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 30min
#             ...
#
#                                          Description  \
# 0      Today - the global war on terror rages on....
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#           None           15 user         18 critic
#
#   Imdb_rating Number_of_who_rated
# 0         4,9               1 518
# https://www.imdb.com/title/tt1090646/?ref_=kw_li_i
#                          Name       Director           Writer  \
# 0  City Rats (original title)  Steve M Kelly  Simon Fantauzzo
#
#                Date_release Country Opening_week_usa Budget Gross  \
# 0   24 April 2009 (UK)
#           UK             »
#
#
#
#
#   Cum_world_gross Production_co Run_time  \
# 0
#         94 min        |
#
#                                          Description Age_rating Metascore  \
# 0      Eight haunted people meet and fall apart -...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0           13 user          4 critic         4,9               1 190
# https://www.imdb.com/title/tt0109548/?ref_=kw_li_i
#   Name            Director              Writer  \
# 0  NaN  Phedon Papamichael  Frederick Stroppel
#
#                             Date_release  Country Opening_week_usa Budget  \
# 0   I skoteini plevra tou pathous
#         English
#    »
#
#
#   Gross Cum_world_gross Production_co Run_time  \
# 0
#              NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Julian Jons is a talented but troubled you...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            3 user          5 critic         4,9                  72
# https://www.imdb.com/title/tt0119556/?ref_=kw_li_i
#   Name          Director             Writer Date_release   Country  \
# 0  NaN  Jean-Marc Vallée  Mario Van Peebles
#   See more
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#                                          Description  \
# 0      In the Wild West of the 1800s, a gunman is...
#
#                     Age_rating Metascore Number_of_rewiews Number_of_critics  \
# 0
#                     R
#           None            4 user          2 critic
#
#   Imdb_rating Number_of_who_rated
# 0         4,9                 222
# https://www.imdb.com/title/tt0081044/?ref_=kw_li_i
#   Name     Director      Writer        Date_release  Country Opening_week_usa  \
# 0  NaN  Jerry Paris  James Ritz   Starmakers
#         English             »
#
#
#   Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#
#         97 min      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Ralph Malph from Philly moves to Hollywood...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            1 user          1 critic         4,9                  40
# https://www.imdb.com/title/tt0166123/?ref_=kw_li_i
#   Name       Director         Writer            Date_release  Country  \
# 0  NaN  Adam Kreutner  Adam Kreutner   Crossing Paths
#         English
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#
#    NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      Jeremy is a college student whose only car...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         4,9                  73
# https://www.imdb.com/title/tt0094254/?ref_=kw_li_i
#   Name           Director             Writer              Date_release  \
# 0  NaN  Jeanine Meerapfel  Jeanine Meerapfel   Days to Remember
#
#
#   Country Opening_week_usa Budget Gross Cum_world_gross Production_co  \
# 0  German    1.85 : 1
#
#    NaN             NaN           NaN
#
#   Run_time                                        Description Age_rating  \
# 0      NaN      Katharina, a German journalist of Yugoslav...
#
#
#   Metascore Number_of_rewiews Number_of_critics Imdb_rating  \
# 0       NaN               NaN               NaN         4,9
#
#   Number_of_who_rated
# 0                  25
# https://www.imdb.com/title/tt0247953/?ref_=kw_li_i
#   Name     Director          Writer                  Date_release  Country  \
# 0  NaN  Sonia Fritz  Eliseo Alberto   The Kiss You Gave Me
#         Spanish
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#      NaN             NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A story of romance and suspense in Puerto ...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            2 user               NaN         4,9                  41
# https://www.imdb.com/title/tt0252848/?ref_=kw_li_i
#   Name           Director             Writer      Date_release Country  \
# 0  NaN  Adonis Lykouresis  Adonis Lykouresis   Alcestes
#          Greek
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0
#    »
#
#              NaN           NaN      NaN
#
#                                          Description Age_rating Metascore  \
# 0      A writer goes to his hometown, looking for...
#        NaN
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0               NaN               NaN         4,9                   7
# https://www.imdb.com/title/tt1034036/?ref_=kw_li_i
#   Name       Director       Writer              Date_release Country  \
# 0  NaN  Sean Plemmons  Jeff Hassen   October 2006 (USA)
#          USA
#
#   Opening_week_usa Budget Gross Cum_world_gross Production_co Run_time  \
# 0             »
#
#
#    1.85 : 1
#              Color      NaN
#
#                                          Description Age_rating Metascore  \
# 0      What has thrills, chills, and rednecks sav...
#       None
#
#   Number_of_rewiews Number_of_critics Imdb_rating Number_of_who_rated
# 0            0 user          1 critic         4,9                  21
# https://www.imdb.com/title/tt0411705/?ref_=kw_li_i
#                        Name              Director          Writer  \
# 0  9 Songs (original title)  Michael Winterbottom  Kieran O'Brien
#
#            Date_release  Country  Opening_week_usa      Budget  \
# 0   Девять песен
#         English   $66,853           $13,457,
#
#
#                  Gross Cum_world_gross Production_co  \
# 0   $1,590,308
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 11min
#             ...
#
#                                          Description  \
# 0      Matt, a young glaciologist, soars across t...
#
#                       Age_rating Metascore Number_of_rewiews  \
# 0
#                     18+
#             43          221 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0        135 critic         4,8              20 833
# https://www.imdb.com/title/tt0411951/?ref_=kw_li_i
#                       Name          Director           Writer  \
# 0  Tekken (original title)  Dwight H. Little  Alan B. McElroy
#
#                       Date_release Country     Opening_week_usa  \
# 0   11 November 2010 (Russia)
#        Japan   $1,697,207
#
#                      Budget Gross Cum_world_gross Production_co  \
# 0  $30,000,000
#
#             »
#              NaN
#
#                                             Run_time  \
# 0
#                         1h 27min
#             ...
#
#                                          Description  \
# 0      The year is 2039. World wars have destroye...
#
#                       Age_rating Metascore Number_of_rewiews  \
# 0
#                     16+
#           None          113 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         71 critic         4,8              25 505
# https://www.imdb.com/title/tt0409011/?ref_=kw_li_i
#                             Name        Director            Writer  \
# 0  Love Wrecked (original title)  Randal Kleiser  Stephen Langford
#
#                  Date_release Country Opening_week_usa               Budget  \
# 0   8 June 2006 (Russia)
#          USA
#    $3,505,963
#
#    Gross Cum_world_gross Production_co  \
# 0   »
#
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 27min
#             ...
#
#                                          Description  \
# 0      On a Caribbean cruise, Jenny is marooned o...
#
#                         Age_rating Metascore Number_of_rewiews  \
# 0
#                     PG-13
#           None           28 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         28 critic         4,8              13 721
# https://www.imdb.com/title/tt0106471/?ref_=kw_li_i
#                              Name        Director           Writer  \
# 0  Boxing Helena (original title)  Jennifer Lynch  Philippe Caland
#
#                    Date_release Country     Opening_week_usa       Budget  \
# 0   3 September 1993 (USA)
#          USA   $1,796,389           $787,724,
#
#
#                  Gross Cum_world_gross Production_co  \
# 0   $1,796,389
#            NaN
#
#                                             Run_time  \
# 0
#                         1h 47min
#             ...
#
#                                          Description  \
# 0      A top surgeon is besotted with a beautiful...
#
#                       Age_rating Metascore Number_of_rewiews  \
# 0
#                     18+
#             26          124 user
#
#   Number_of_critics Imdb_rating Number_of_who_rated
# 0         40 critic         4,8              11 041
